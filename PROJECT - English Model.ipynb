# %%
import pandas as pd
import string
import random
from pathlib import Path
import csv
import spacy
from spacy import displacy
from spacy.util import minibatch,compounding

# %%
data=pd.read_csv("/home/rebel/Downloads/project/training_data.csv")

# %%
data.shape
# Out:
# (100, 4)

# %%
data.head(5)
# Out:
#             DR  crime_code                                          NARRATIVE  \
# 0  120120958.0       623.0  AFTER PLACING SUSPECT UNDER ARREST FOR PPA BAT...
# 1  120120929.0       624.0  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 2  120120928.0       624.0  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 3  121920543.0       624.0  VICTIM SUSPECT INVOLVED IN ARGUMENT SUSPECT PU...
# 4  121425107.0       624.0  VICTIM AND SUSPECT ARE IN COHAB RELATIONSHIP V...
#
#   classification
# 0          minor
# 1          minor
# 2          minor
# 3          minor
# 4          minor

# %%
data.dropna(axis=1)
data.head(5)
# Out:
#             DR  crime_code                                          NARRATIVE  \
# 0  120120958.0       623.0  AFTER PLACING SUSPECT UNDER ARREST FOR PPA BAT...
# 1  120120929.0       624.0  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 2  120120928.0       624.0  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 3  121920543.0       624.0  VICTIM SUSPECT INVOLVED IN ARGUMENT SUSPECT PU...
# 4  121425107.0       624.0  VICTIM AND SUSPECT ARE IN COHAB RELATIONSHIP V...
#
#   classification
# 0          minor
# 1          minor
# 2          minor
# 3          minor
# 4          minor

# %%
data=data.drop(['DR', 'crime_code','classification'], axis = 1) 
data.head(5)
# Out:
#                                            NARRATIVE
# 0  AFTER PLACING SUSPECT UNDER ARREST FOR PPA BAT...
# 1  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 2  VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL A...
# 3  VICTIM SUSPECT INVOLVED IN ARGUMENT SUSPECT PU...
# 4  VICTIM AND SUSPECT ARE IN COHAB RELATIONSHIP V...

# %%
data["NARRATIVE"][0]
# Out:
# 'AFTER PLACING SUSPECT UNDER ARREST FOR PPA BATTERY SUSPECT USING HIS RIGHT LEG KICKED POLICE SERGEANT IN THE BACK'

# %%
data.to_csv(r'/home/rebel/Documents/new1.csv', index = False)

# %%
csv_file = input('Enter the name of your input file: ')
txt_file = input('Enter the name of your output file: ')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# Enter the name of your input file: /home/rebel/Documents/new1.csv
# Enter the name of your output file: /home/rebel/Documents/english_data.txt

# %% [markdown]
# # WORKING WITH NER

# %%
nlp=spacy.blank("xx")

nlp.add_pipe(nlp.create_pipe('ner'))

nlp.begin_training()
# Out:
# /home/rebel/.local/lib/python3.8/site-packages/spacy/language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
train_data = [('AFTER PLACING SUSPECT UNDER ARREST FOR PPA BATTERY THEFT SUSPECT USING HIS RIGHT LEG KICKED POLICE SERGEANT IN THE BACK', {'entities': [(92, 107, 'Public Service Officer'), (85, 91, 'ACTIVITY'), (75, 84, 'Part of Human Body'), (57, 64, 'SUSPECT'), (51, 56, 'CRIME'), (28, 34, 'ACTIVITY'), (14, 21, 'SUSPECT'), (6, 13, 'ACTIVITY')]}), ('VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL ARGUMENT SUSPECT THEN BEGAN HITTING VICTIM IN THE FACE', {'entities': [(95, 99, 'Part of Human Body'), (81, 87, 'VICTIM'), (73, 80, 'ACTIVITY'), (54, 61, 'SUSPECT'), (38, 53, 'ACTIVITY'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM AND SUSPECT BECAME INVOLVED IN VERBAL ARGUMENT SUSPECT THEN BEGAN HITTING VICTIM IN THE FACE', {'entities': [(95, 99, 'Part of Human Body'), (81, 87, 'VICTIM'), (73, 80, 'ACTIVITY'), (54, 61, 'SUSPECT'), (38, 53, 'ACTIVITY'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM SUSPECT INVOLVED IN ARGUMENT SUSPECT PUNCHED VICTIMS FACE TORSO', {'entities': [(60, 70, 'Part of Human Body'), (52, 59, 'VICTIM'), (44, 51, 'ACTIVITY'), (36, 43, 'SUSPECT'), (27, 35, 'ACTIVITY'), (7, 14, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM AND SUSPECT ARE IN COHAB RELATIONSHIP VICTIM SLAPPED SUSPECT SUSPECT STRANGLED VICTIM FOR APPROX 1 SECOND NO INJURIES', {'entities': [(104, 112, 'TIME'), (86, 92, 'VICTIM'), (76, 85, 'ACTIVITY'), (68, 75, 'SUSPECT'), (60, 67, 'SUSPECT'), (52, 59, 'ACTIVITY'), (45, 51, 'VICTIM'), (26, 44, 'Relationship'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM AND HUSBAND IN VERBAL ARGUMENT SUSPECT HIT VICTIM IN FACE', {'entities': [(60, 64, 'Part of Human Body'), (50, 56, 'VICTIM'), (46, 49, 'ACTIVITY'), (38, 45, 'SUSPECT'), (22, 37, 'ACTIVITY'), (11, 18, 'Relation'), (0, 6, 'VICTIM')]}), ('VICTIM ADVISED SUSPECT TO REMOVE PROP FROM THE SIDEWALK SUSPECT BEGAN TO YELL AT VICTIM AND THEN SPIT IN THE VICTIM FACE', {'entities': [(116, 120, 'Part of Human Body'), (109, 115, 'VICTIM'), (81, 87, 'VICTIM'), (73, 77, 'ACTIVITY'), (56, 63, 'SUSPECT'), (33, 37, 'OBJECT'), (26, 32, 'ACTIVITY'), (15, 22, 'SUSPECT'), (7, 14, 'ACTIVITY'), (0, 6, 'VICTIM')]}), ('VICTIM WAS WALKING ON SIDEWALK WHEN SUSPECT CONFRONTED HIM SUSPECT APPROACHED PUNCHING AND KICKING VICTIM', {'entities': [(99, 105, 'VICTIM'), (91, 99, 'ACTIVITY'), (78, 86, 'ACTIVITY'), (59, 66, 'SUSPECT'), (36, 43, 'SUSPECT'), (11, 18, 'ACTIVITY'), (0, 6, 'VICTIM')]}), ('VICTIM WAS PUSHED BY SUSPECT ON CHEST TWICE CAUSING VICTIM TO FALL TO GROUND SUSPECT FLED STRAIGHT ON AIRPORT IN VEHICLE', {'entities': [(113, 120, 'VEHICLE'), (102, 109, 'LOCATION'), (77, 84, 'SUSPECT'), (52, 58, 'VICTIM'), (32, 37, 'Part of Human Body'), (21, 28, 'SUSPECT'), (11, 17, 'ACTIVITY'), (0, 6, 'VICTIM')]}), ('VICTIM IS SECURITY GUARD AT TACO BELL SUSPECT THREW A CUP OF SODA IN VICTIM FACE AFTER BEING TOLD TO LEAVE RESTAURANT', {'entities': [(107, 117, 'LOCATION'), (76, 80, 'Part of Human Body'), (69, 75, 'VICTIM'), (38, 45, 'SUSPECT'), (28, 37, 'LOCATION'), (10, 24, 'Public Service Officer'), (0, 6, 'VICTIM')]}), ('VICTIM IS SUSPECTS MOTHER SUSPECT BECAME ANGRY AT VICTIM AND PUNCHED HER IN THE FACE TWICE CAUSING INJURY SUSPECT FLED TO A LOCATION IN UNKNOWN DIRECTION', {'entities': [(124, 132, 'LOCATION'), (106, 113, 'SUSPECT'), (80, 84, 'Part of Human Body'), (61, 68, 'ACTIVITY'), (50, 56, 'VICTIM'), (41, 46, 'SENTIMENT'), (26, 33, 'SUSPECT'), (19, 25, 'Relation'), (10, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('UNKNOWN SUSPECT ATTACKED VICTIM UNKNOWN OF ANY WEAPONS USED VICTIM UNCONSCIOUS AT HOSPITAL DUE TO MEDICATION UNABLE TO INTERVIEW', {'entities': [(82, 90, 'LOCATION'), (60, 66, 'VICTIM'), (47, 54, 'OBJECT'), (25, 31, 'VICTIM'), (16, 24, 'ACTIVITY'), (8, 15, 'SUSPECT')]}), ('SUSPECT VICTIM INVOLVED IN ARGUMENT OVER STOLENPROP SUSPECT THREW CUP OF SODA AT VICTIM HITTING HER ON NECK UPPER CHEST', {'entities': [(103, 119, 'Part of Human Body'), (88, 95, 'ACTIVITY'), (81, 87, 'VICTIM'), (52, 59, 'SUSPECT'), (41, 51, 'OBJECT'), (27, 35, 'ACTIVITY'), (8, 14, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT WILLFULLY AND UNLAWFULLY WITH HIS RIGHT FIST PUNCHED VICTIM IN THE FACE', {'entities': [(75, 79, 'Part of Human Body'), (61, 67, 'VICTIM'), (53, 60, 'ACTIVITY'), (42, 52, 'Part of Human Body'), (0, 7, 'SUSPECT')]}), ('SUSPECT STURCK VICTIM TWICE WITH CLOSED FISTS ON RIGHT SIDE OF FACE SUSPECT THEN FLED TO A LOCATION IN UNKNOWN DIRECTION', {'entities': [(91, 99, 'LOCATION'), (68, 75, 'SUSPECT'), (63, 67, 'Part of Human Body'), (33, 45, 'Part of Human Body'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT STRUCK VICTIM ON FACE WITH CLOSED FISTS AFTER LOSING A LUNCH BET SUSPECT THEN FOLLOWED VICTIM TOWARDS PARKING LOT AND THREATENED TO CONTINUE HITTING VICTIM', {'entities': [(157, 163, 'VICTIM'), (149, 156, 'ACTIVITY'), (110, 121, 'LOCATION'), (95, 101, 'VICTIM'), (73, 80, 'SUSPECT'), (35, 47, 'Part of Human Body'), (25, 29, 'Part of Human Body'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT STRUCK VICTIM IN FACE AND LEG WITH CLOSED FISTS LEAVING VISIBLE INJURIES SUSPECT FLED TO A LOCATION IN UNKNOWN DIRECTION', {'entities': [(99, 107, 'LOCATION'), (81, 88, 'SUSPECT'), (43, 55, 'Part of Human Body'), (34, 37, 'Part of Human Body'), (25, 29, 'Part of Human Body'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT PUSHED VICTIM', {'entities': [(15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENTERED THE STORE AND BECAME INVOLVED WITH VICTIM SUSPECT BECAME ANGRY AND THREW THE CHOCOLATE CANDY AT THE VICTIM FACE', {'entities': [(123, 127, 'Part of Human Body'), (116, 122, 'VICTIM'), (93, 108, 'OBJECT'), (73, 78, 'SENTIMENT'), (58, 65, 'SUSPECT'), (51, 57, 'VICTIM'), (20, 25, 'LOCATION'), (0, 7, 'SUSPECT')]}), ('SUSPECT BEGAN YELLING AT VICTIM BECAUSE SUSPECT WAS UNHAPPY THAT VICTIM ASKED HIM TO MOVE SUSPECT PUNCHED VICTIM IN THE RIGHT CHEECK WITH CLOSED FIST THEN FLED SAN BERNARDINO SPEEDWAY', {'entities': [(160, 183, 'LOCATION'), (138, 149, 'Part of Human Body'), (120, 132, 'Part of Human Body'), (106, 112, 'VICTIM'), (98, 105, 'ACTIVITY'), (90, 97, 'SUSPECT'), (65, 71, 'VICTIM'), (52, 59, 'SENTIMENT'), (40, 47, 'SUSPECT'), (25, 31, 'VICTIM'), (14, 21, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM WHILE SHE WAS SEATED SUSPECT WAS FLEEING FROM SECURITY SUSPECT STROKED VICTIM LEG AS HE PASSED BY VICTIM SUSPECT FLED TO A LOCATION ON FOOT', {'entities': [(161, 165, 'Part of Human Body'), (149, 157, 'LOCATION'), (131, 138, 'SUSPECT'), (124, 130, 'VICTIM'), (104, 107, 'Part of Human Body'), (97, 103, 'VICTIM'), (89, 96, 'ACTIVITY'), (81, 88, 'SUSPECT'), (72, 80, 'Public Service Officer'), (47, 54, 'SUSPECT'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM AND STRUCK HIM ON FACE SUSPECT GRABBED VICTIM PHONE AND FLED TO A LOCATION', {'entities': [(92, 100, 'LOCATION'), (72, 77, 'OBJECT'), (65, 71, 'VICTIM'), (57, 64, 'ACTIVITY'), (49, 56, 'SUSPECT'), (44, 48, 'Part of Human Body'), (30, 36, 'ACTIVITY'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM FROM BEHIND AND GRABBED HER VICTIM STRUGGLED TO BREAK SUSPECT HOLD AND RECEIVED A LACERATION TO RIGHT ARM BY UNKNOWN OBJECT SUSPECT FLED ON FOOT', {'entities': [(166, 170, 'Part of Human Body'), (150, 157, 'SUSPECT'), (135, 149, 'OBJECT'), (122, 131, 'Part of Human Body'), (108, 118, 'Injury'), (80, 87, 'SUSPECT'), (74, 79, 'ACTIVITY'), (54, 60, 'VICTIM'), (42, 49, 'ACTIVITY'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ENGAGED IN DISPUTE SUSPECT BECAME ENRAGED AND STRUCK VICTIM IN THE FACE', {'entities': [(86, 90, 'Part of Human Body'), (72, 78, 'VICTIM'), (65, 71, 'ACTIVITY'), (53, 60, 'SENTIMENT'), (38, 45, 'SUSPECT'), (30, 37, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ENGAGED IN AN ARGUMENT SUSPECT BECAME ANGRY AND GRABBED THE VICTIM BY THE ARM VICTIM PULLED AWAY CAUSING HURT TO HER HEAD', {'entities': [(136, 140, 'Part of Human Body'), (124, 128, 'Injury'), (97, 103, 'VICTIM'), (93, 96, 'Part of Human Body'), (79, 85, 'VICTIM'), (67, 74, 'ACTIVITY'), (57, 62, 'SENTIMENT'), (42, 49, 'SUSPECT'), (33, 41, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM INVOLVED IN ARGUMENT SUSPECT SPIT IN VICTIM FACE', {'entities': [(63, 67, 'Part of Human Body'), (56, 62, 'VICTIM'), (48, 52, 'ACTIVITY'), (40, 47, 'SUSPECT'), (31, 39, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT1 PUSHED VICTIM TO THE GROUND SUSPECT1 LEFT AND RETURNED WITH SUSPECT2 SUSPECT2 PUSHED VICTIM TO THE GROUND SUSPECTS FLED ON FOOT', {'entities': [(132, 136, 'Part of Human Body'), (115, 123, 'SUSPECT'), (94, 100, 'VICTIM'), (78, 86, 'SUSPECT'), (69, 77, 'SUSPECT'), (37, 45, 'SUSPECT'), (16, 22, 'VICTIM'), (0, 8, 'SUSPECT')]}), ('SUSPECT WAS INVOLVED IN A PHYSICAL ALTERCATION WITH VICTIM SUSPECT PUNCHED AND KICKED VICTIM ON THE CHEST AND LEG AREA SUSPECT FLED TOWARDS UNKNOWN LOCATION', {'entities': [(140, 156, 'LOCATION'), (119, 126, 'SUSPECT'), (110, 113, 'Part of Human Body'), (100, 105, 'Part of Human Body'), (86, 92, 'VICTIM'), (79, 85, 'ACTIVITY'), (67, 74, 'ACTIVITY'), (59, 66, 'SUSPECT'), (52, 58, 'VICTIM'), (26, 46, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT THREW BASKETBALL AT VICTIM STRIKING VICTIM FACE', {'entities': [(51, 55, 'Part of Human Body'), (44, 50, 'VICTIM'), (35, 43, 'ACTIVITY'), (28, 34, 'VICTIM'), (14, 24, 'OBJECT'), (0, 7, 'SUSPECT')]}), ('SUSPECT STRUCK VICTIM ON ARM WITH A WOODEN BROOM', {'entities': [(36, 48, 'OBJECT'), (25, 28, 'Part of Human Body'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT PUSHED VICTIM CAUSING VICTIM TO STEP BACK WHILE IN APARTMENT BUILDING ELEVATOR', {'entities': [(59, 86, 'LOCATION'), (30, 36, 'VICTIM'), (15, 21, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT GRABBED VICTIM WRIST AND PUSHED HER DOWN DURING VERBAL DISPUTE', {'entities': [(56, 70, 'ACTIVITY'), (33, 39, 'ACTIVITY'), (23, 28, 'Part of Human Body'), (16, 22, 'VICTIM'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT GOT IN ARGUMENT WITH VICTIM OVER BEING ASKED TO LEAVE SUSPECT PUNCHED VICTIM WITH A CLOSED FIST SUSPECT FLED LOCATION IN UNKNOWN DIRECTION', {'entities': [(117, 125, 'LOCATION'), (92, 103, 'Part of Human Body'), (78, 84, 'VICTIM'), (70, 77, 'ACTIVITY'), (62, 69, 'SUSPECT'), (29, 35, 'VICTIM'), (15, 23, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENGAGED VICTIM IN VERBAL DISPUTE SUSPECT THEN PUSHED VICTIM AND PUNCHED VICTIM ON RIGHT CHEEKWITH CLOSED FIST', {'entities': [(106, 117, 'Part of Human Body'), (90, 101, 'Part of Human Body'), (80, 86, 'VICTIM'), (72, 79, 'ACTIVITY'), (61, 67, 'VICTIM'), (54, 60, 'ACTIVITY'), (41, 48, 'SUSPECT'), (26, 40, 'ACTIVITY'), (16, 22, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENGAGED VICTIM IN VERBAL DISPUTE SUSPECT THEN PUSHED VICTIM AND PUNCHED VICTIM ON RIGHT CHEEK WITH CLOSED FIST', {'entities': [(107, 118, 'Part of Human Body'), (90, 101, 'Part of Human Body'), (80, 86, 'VICTIM'), (72, 79, 'ACTIVITY'), (61, 67, 'VICTIM'), (54, 60, 'ACTIVITY'), (41, 48, 'SUSPECT'), (26, 40, 'ACTIVITY'), (16, 22, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENGAGED VICTIM IN VERBAL DISPUTE SUSPECT SMASHED VICTIM RIGHT HAND IN DOOR VICTIM OPENED DOOR AND FELL TO HER KNEES SUSPECT THEN KNEED VICTIM ON RIGHT BREAST', {'entities': [(153, 165, 'Part of Human Body'), (143, 149, 'VICTIM'), (124, 131, 'SUSPECT'), (118, 123, 'Part of Human Body'), (97, 101, 'OBJECT'), (83, 89, 'VICTIM'), (78, 82, 'OBJECT'), (64, 74, 'Part of Human Body'), (57, 63, 'VICTIM'), (49, 56, 'ACTIVITY'), (41, 48, 'SUSPECT'), (26, 40, 'ACTIVITY'), (16, 22, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT CAME UP FROM BEHIND WHILE VICTIM WAS URINATING PLACED BOTH HANDS ON SHOULDERS AND SHOOK VICTIM HARD SUSPECT THEN LEFT RESTROOM LAUGHING', {'entities': [(135, 143, 'SENTIMENT'), (126, 134, 'LOCATION'), (108, 115, 'SUSPECT'), (96, 102, 'VICTIM'), (90, 95, 'ACTIVITY'), (76, 85, 'Part of Human Body'), (67, 72, 'Part of Human Body'), (45, 54, 'ACTIVITY'), (34, 40, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT ARRIVED AT LOCATION AND BEGAN TO ARGUE WITH VICTIM SUSPECT REPEATEDLY KICKED AND PUNCHED VICTIM SUSPECT FLED LOCATION RETURNED AND AGAIN PUNCHED AND KICKED VICTIM', {'entities': [(164, 170, 'VICTIM'), (157, 163, 'ACTIVITY'), (145, 152, 'ACTIVITY'), (117, 125, 'LOCATION'), (104, 111, 'SUSPECT'), (97, 103, 'VICTIM'), (89, 96, 'ACTIVITY'), (78, 84, 'ACTIVITY'), (59, 66, 'SUSPECT'), (52, 58, 'VICTIM'), (41, 46, 'ACTIVITY'), (19, 27, 'LOCATION'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('INCIDENT TO ARREST SUSPECT KICKED OFFICER IN THE TORSO', {'entities': [(49, 54, 'Part of Human Body'), (34, 41, 'Public Service Officer'), (27, 33, 'ACTIVITY'), (19, 26, 'SUSPECT'), (12, 18, 'ACTIVITY')]}), ('SUSPECT APPROACHED VICTIM ON FOOT SUSPECT PUNCHED AND KICKED VICTIM SEVERAL TIMES SUSPECT RAN FROM LOCATION TO SANTAMONICA BY VEHICLE', {'entities': [(126, 133, 'VEHICLE'), (111, 122, 'LOCATION'), (99, 107, 'LOCATION'), (90, 93, 'ACTIVITY'), (82, 89, 'SUSPECT'), (61, 67, 'VICTIM'), (54, 60, 'ACTIVITY'), (42, 49, 'ACTIVITY'), (34, 41, 'SUSPECT'), (29, 33, 'Part of Human Body'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM AND PUSHED VICTIM VICTIM FELL BACK TOWARDS DOORWAY AND STRUCK HIS RIGHT ELBOW AS A RESULT', {'entities': [(92, 103, 'Part of Human Body'), (81, 87, 'ACTIVITY'), (69, 76, 'OBJECT'), (44, 50, 'VICTIM'), (37, 43, 'VICTIM'), (30, 36, 'ACTIVITY'), (19, 25, 'VICTIM'), (8, 18, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM WERE IN A VERBAL DISPUTE OVER LAUNDRY MACHINE USE SUSPECT GRABBED VICTIM LEFT ARM AGGRESSIVELY AND LEFT VISIBLE INJURY', {'entities': [(131, 137, 'Injury'), (92, 100, 'Part of Human Body'), (85, 91, 'VICTIM'), (77, 84, 'ACTIVITY'), (69, 76, 'SUSPECT'), (49, 64, 'OBJECT'), (29, 43, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM INVOLVED IN A VERBAL DISPUTE SUSPECT BECAME UPSET AND PUNCHED VICTIM ON HIS FOREHEAD SUSPECT THEN ENTERED VEHICLE AND FLED', {'entities': [(125, 132, 'VEHICLE'), (104, 111, 'SUSPECT'), (95, 103, 'Part of Human Body'), (81, 87, 'VICTIM'), (73, 80, 'ACTIVITY'), (63, 68, 'SENTIMENT'), (48, 55, 'SUSPECT'), (33, 47, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM GOT INTO VERBAL ARGUMENT SUSPECT HIT VICTIM ON HEAD WITH OPEN HAND', {'entities': [(76, 85, 'Part of Human Body'), (66, 70, 'Part of Human Body'), (56, 62, 'VICTIM'), (44, 51, 'SUSPECT'), (28, 43, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ARE ROOMMATES INVOLVED IN DISPUTE THAT ESCALATED TO PUSHING EACH OTHER CAUSING INJURY BOTH PARTIES REFUSED TO PAY FOR MEDICAL TREATMENT', {'entities': [(98, 104, 'Injury'), (71, 78, 'ACTIVITY'), (45, 52, 'ACTIVITY'), (23, 32, 'Relation'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ARE ROOMMATES INVOLVED IN DISPUTE THAT ESCALATED TO PUSHING EACH OTHER CAUSING INJURY BOTH PARTIES REFUSED TO PAY FOR MEDICAL TREATMENT', {'entities': [(98, 104, 'Injury'), (71, 78, 'ACTIVITY'), (45, 52, 'ACTIVITY'), (23, 32, 'Relation'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ARE ADULT SISTERS NOT LIVING TOGETHER BECAME INVOLVED IN A PHYSICAL FIGHT BOTH PARTIES REFUSED TO REPORT', {'entities': [(78, 92, 'ACTIVITY'), (23, 36, 'Relation'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('VICTIM AND SUSPECT SO CALLED SIBLINGS INVOLVED IN VERBAL DISPUTE WHICH ESCALATED INTO PHYSICAL VIOLENCE SUSPECT STRUCK VICTIM WITH COFFEE CUP OVER HEAD', {'entities': [(147, 151, 'Part of Human Body'), (131, 141, 'OBJECT'), (119, 125, 'VICTIM'), (112, 118, 'ACTIVITY'), (104, 111, 'SUSPECT'), (86, 103, 'ACTIVITY'), (50, 64, 'ACTIVITY'), (29, 37, 'Relation'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM STATED THAT SHE WAS INSIDE THE BAR WHEN SUSPECT APPROACHED HER AND HIT HER OVER LEFT EYE CAUSING APPROX 2 INCH LACERATION THEN FLED IN UNKNOWN DIRECTION', {'entities': [(118, 128, 'Injury'), (87, 95, 'Part of Human Body'), (74, 77, 'ACTIVITY'), (47, 54, 'SUSPECT'), (38, 41, 'LOCATION'), (0, 6, 'VICTIM')]}), ('VICTIM ATTENDED A PARTY IN THE AREA OF 4TH STREET OF LORENA WHILE IN THE BACK YARD VICTIM HEARD ONE GUN SHOT THE VICTIM THEN NOTICED HE WAS STRUCK BY A BULLET', {'entities': [(152, 158, 'OBJECT'), (140, 146, 'ACTIVITY'), (125, 132, 'ACTIVITY'), (113, 119, 'VICTIM'), (83, 89, 'VICTIM'), (73, 82, 'LOCATION'), (39, 59, 'LOCATION'), (0, 6, 'VICTIM')]}), ('UNKNOWN SUSPECT STRUCK THE VICTIM IN THE HEAD DURING ALTERCATION AT PARTY RELATED TO GANG HOMICIDE DR 121616375', {'entities': [(85, 98, 'CRIME'), (53, 64, 'ACTIVITY'), (41, 45, 'Part of Human Body'), (27, 33, 'VICTIM'), (16, 22, 'ACTIVITY'), (8, 15, 'SUSPECT')]}), ('UNKNOWN SUSPECT APPROCHED VICTIM WHILE VICTIM WAS SLEEPING INSIDE VEHICLE UNKNOWN SUSPECT FIRED 3-4 ROUNDS WITH UNKNOWN HANDGUN SUSPECT FLED TO LOCATION WB 77TH ST', {'entities': [(144, 163, 'LOCATION'), (128, 135, 'SUSPECT'), (120, 127, 'OBJECT'), (82, 89, 'SUSPECT'), (66, 73, 'VEHICLE'), (50, 58, 'ACTIVITY'), (39, 45, 'VICTIM'), (26, 32, 'VICTIM'), (8, 15, 'SUSPECT')]}), ('SUSPECTS RODE TOGETHER ON BICYCLES SUSPECT1 ASKED VICTIM WHERE YOU FROM SUSPECT1 SHOT AT VICTIM STRIKING HIM IN GROIN SUSPECTS FLED', {'entities': [(118, 126, 'SUSPECT'), (112, 117, 'Part of Human Body'), (96, 104, 'ACTIVITY'), (89, 95, 'VICTIM'), (81, 85, 'ACTIVITY'), (72, 80, 'SUSPECT'), (50, 56, 'VICTIM'), (35, 43, 'SUSPECT'), (26, 34, 'VEHICLE'), (9, 13, 'ACTIVITY'), (0, 8, 'SUSPECT')]}), ('SUSPECT SHOWED KNIFE ON VICTIM AND STABBED VICTIM VICTIM PUSHED BACK GOT CUT SUSPECT HEADDBUTTED VICTIM AND FLED LOCATION IN UNKNOWN DIRECTION BY VEHICLE', {'entities': [(146, 153, 'VEHICLE'), (97, 103, 'VICTIM'), (85, 89, 'Part of Human Body'), (77, 84, 'SUSPECT'), (73, 76, 'Injury'), (57, 63, 'ACTIVITY'), (50, 56, 'VICTIM'), (43, 49, 'VICTIM'), (35, 42, 'ACTIVITY'), (24, 30, 'VICTIM'), (15, 20, 'OBJECT'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT THREW A GLASS BOTTLE AT VICTIMS HEAD AFTER VICTIM TOLD SUSPECT NOT TO SPIT IN HIS DIRECTION', {'entities': [(78, 82, 'ACTIVITY'), (63, 70, 'SUSPECT'), (58, 62, 'ACTIVITY'), (51, 57, 'VICTIM'), (40, 44, 'Part of Human Body'), (32, 39, 'VICTIM'), (16, 28, 'OBJECT'), (8, 13, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT GRABBED THE BACK OF VICTIM NECK THEN PUSHED SHARP OBJECT SPEARS INTO VICTIM STOMACH', {'entities': [(84, 91, 'Part of Human Body'), (77, 83, 'VICTIM'), (52, 64, 'OBJECT'), (45, 51, 'ACTIVITY'), (35, 39, 'Part of Human Body'), (28, 34, 'VICTIM'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENTERED RESIDENCE WHILE VICTIM WAS INSIDE POURED GASOLINE INSIDE RESIDENCE WHILE STATING IF YOUR NOT GOING TO LET ME IN I WILL BURN YOU OUT VICTIM FLED', {'entities': [(148, 154, 'VICTIM'), (135, 139, 'ACTIVITY'), (89, 96, 'ACTIVITY'), (73, 82, 'LOCATION'), (50, 56, 'ACTIVITY'), (32, 38, 'VICTIM'), (16, 25, 'LOCATION'), (0, 7, 'SUSPECT')]}), ('SUSPECT ENTERED RESIDENCE WHILE VICTIM WAS INSIDE POURED GASOLINE INSIDE RESIDENCE WHILE STATING IF YOUR NOT GOING TO LET ME IN I WILL BURN YOU OUT VICTIM FLED', {'entities': [(148, 154, 'VICTIM'), (135, 139, 'ACTIVITY'), (89, 96, 'ACTIVITY'), (73, 82, 'LOCATION'), (50, 56, 'ACTIVITY'), (32, 38, 'VICTIM'), (16, 25, 'LOCATION'), (0, 7, 'SUSPECT')]}), ('SUSPECT BECAME ANGRY AT THE VICTIM FOR LOOKING AT HIS GIRLFRIEND SUSPECT THEN HIT THE VICTIM ON THE HEAD AND IN THE FACE WITH A FLASHLIGHT', {'entities': [(128, 138, 'OBJECT'), (116, 120, 'Part of Human Body'), (100, 104, 'Part of Human Body'), (86, 92, 'VICTIM'), (78, 81, 'ACTIVITY'), (65, 72, 'SUSPECT'), (54, 64, 'Relation'), (28, 34, 'VICTIM'), (15, 20, 'Injury'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM FOR UNKNOWN REASON SUSPECT HIT VICTIM WITH BAT ON LEFT ARM VICTIM RAN AWAY FROM SUSPECT WITHOUT FURTHER INVOLVEMENT', {'entities': [(106, 113, 'SUSPECT'), (92, 95, 'ACTIVITY'), (85, 91, 'VICTIM'), (76, 84, 'Part of Human Body'), (69, 72, 'OBJECT'), (57, 63, 'VICTIM'), (53, 56, 'ACTIVITY'), (45, 52, 'SUSPECT'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM GOT INTO AN ARGUMENT SUSPECTS KNOCKED VICTIM UNCONSCIOUS WHILE VICTIM WAS ON THE GROUND SUSPECT KICKED VICTIM MULTIPLE TIMES SUSPECT FLED IN UNKNOWN DIRECTION', {'entities': [(144, 151, 'SUSPECT'), (122, 128, 'VICTIM'), (115, 121, 'ACTIVITY'), (107, 114, 'SUSPECT'), (100, 106, 'LOCATION'), (82, 88, 'VICTIM'), (57, 63, 'VICTIM'), (49, 56, 'ACTIVITY'), (40, 48, 'SUSPECT'), (31, 39, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT SLAMMED FRONT DRIVER DOOR OF HIS VEHICLE AGAINST VICTIMS VEHICLE AND SCRATCHED VICTIM VEHICLE WITH A KEY SUSPECT THEN USED HIS VEHICLE TO HIT VICTIMS VEHICLE AND ATTEMPTED TO GO AWAY', {'entities': [(158, 165, 'VEHICLE'), (150, 157, 'VICTIM'), (146, 149, 'ACTIVITY'), (135, 142, 'VEHICLE'), (113, 120, 'SUSPECT'), (109, 112, 'OBJECT'), (94, 101, 'VEHICLE'), (87, 93, 'VICTIM'), (77, 86, 'ACTIVITY'), (65, 72, 'VEHICLE'), (57, 64, 'VICTIM'), (41, 48, 'VEHICLE'), (29, 33, 'OBJECT'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT CUT VICTIM WITH UNKNOWN SHARP OBJECT WHILE INVOLVED IN A FIST FIGHT', {'entities': [(65, 69, 'Part of Human Body'), (32, 44, 'OBJECT'), (12, 18, 'VICTIM'), (8, 11, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM WERE INVOLVED IN A DISPUTE SUSPECT GRABBED BOX CUTTER HELD IT TO VICTIM NECK AND STOMACH SUSPECT THREATENED TO KILL VICTIM', {'entities': [(135, 141, 'VICTIM'), (130, 134, 'CRIME'), (108, 115, 'SUSPECT'), (100, 107, 'Part of Human Body'), (91, 95, 'Part of Human Body'), (84, 90, 'VICTIM'), (62, 72, 'OBJECT'), (46, 53, 'SUSPECT'), (38, 45, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM WERE DRINKING TOGETHER SUSPECT GOT UPSET AND STRUCK VICTIM IN FACE WITH GLASSCOKE BOTTLE SUSPECT FLED TO UNKNOWN DIRECTION ON VERMONT', {'entities': [(145, 152, 'VEHICLE'), (108, 115, 'SUSPECT'), (91, 107, 'OBJECT'), (81, 85, 'Part of Human Body'), (71, 77, 'VICTIM'), (64, 70, 'ACTIVITY'), (54, 59, 'SENTIMENT'), (42, 49, 'SUSPECT'), (24, 32, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIMS VEHICLE WHILE VICTIM WAS SEATED IN VEHICLE SUSPECT OPENED DRIVER DOOR STRUCK VICTIM ON LEG WITH SHOTGUN AND YELLED BITCH', {'entities': [(135, 141, 'ACTIVITY'), (123, 130, 'OBJECT'), (114, 117, 'Part of Human Body'), (104, 110, 'VICTIM'), (97, 103, 'ACTIVITY'), (92, 96, 'OBJECT'), (78, 84, 'ACTIVITY'), (70, 77, 'SUSPECT'), (62, 69, 'VEHICLE'), (41, 47, 'VICTIM'), (27, 34, 'VEHICLE'), (19, 26, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT DISCIPLINE CHILD BY HITTING THEM WITH A WOODEN CHAIR', {'entities': [(48, 60, 'OBJECT'), (28, 35, 'ACTIVITY'), (8, 18, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('VICTIM IS THE SUSPECTS LANDLORD SUSPECTS THREATENED TO KILL THE VICTIM AND THE VICTIMS FAMILY THEN STRUCK THE VICTIM IN THE BACK WITH A 2 X 4 AND BROKE VEHICLE WINDOW', {'entities': [(160, 166, 'OBJECT'), (152, 159, 'VEHICLE'), (146, 151, 'ACTIVITY'), (110, 116, 'VICTIM'), (99, 105, 'ACTIVITY'), (87, 93, 'Relation'), (79, 86, 'VICTIM'), (64, 70, 'VICTIM'), (55, 59, 'CRIME'), (32, 40, 'SUSPECT'), (14, 22, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM CONTACTED POLICE DEPARTMENT FOR 507P NEIGHBOUR SUSPECT BECAME UPSET ARGUMENT ENSURED SUSPECT ENTERED VICTIMS RESIDENCE HIT VICTIM WITH BASEBALL BAT', {'entities': [(142, 154, 'OBJECT'), (130, 136, 'VICTIM'), (116, 125, 'LOCATION'), (108, 115, 'VICTIM'), (92, 99, 'SUSPECT'), (75, 83, 'ACTIVITY'), (69, 74, 'SENTIMENT'), (54, 61, 'SUSPECT'), (17, 34, 'Public Service Officer'), (0, 6, 'VICTIM')]}), ('VICTIM AND SUSPECT BECAME ENGAGED IN A HEATED ARGUMENT SUSPECT THEN THREW A WOODEN CHAIR AT VICTIM STRIKING HIM ON HIS RIGHT ARM SUSPECT THEN BRANDISHED A KNIFE', {'entities': [(155, 160, 'OBJECT'), (129, 136, 'SUSPECT'), (119, 128, 'Part of Human Body'), (99, 107, 'ACTIVITY'), (92, 98, 'VICTIM'), (76, 88, 'OBJECT'), (55, 62, 'SUSPECT'), (46, 54, 'ACTIVITY'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('VICTIM AND SUSPECT WERE INVOLVED IN A VERBAL DISPUTE WHICH ESCALATED INTO A PHYSICAL ALTERCATION THE SUSPECT SLASHED VICTIM NOSE AND CHEEK WITH KNIFE', {'entities': [(144, 149, 'OBJECT'), (133, 138, 'Part of Human Body'), (124, 128, 'Part of Human Body'), (117, 123, 'VICTIM'), (109, 116, 'ACTIVITY'), (101, 108, 'SUSPECT'), (76, 96, 'ACTIVITY'), (38, 52, 'ACTIVITY'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('SUSPECT STRUCK VICTIM IN HEAD WITH BAR STOOL', {'entities': [(35, 44, 'OBJECT'), (25, 29, 'Part of Human Body'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT PUNCHED VICTIM WITH FISTS AND HIT VICTIM IN THE HEAD WITH A DUMBBELL WHILE VICTIM LAYED IN BED', {'entities': [(99, 102, 'OBJECT'), (90, 95, 'ACTIVITY'), (83, 89, 'VICTIM'), (68, 76, 'OBJECT'), (56, 60, 'Part of Human Body'), (42, 48, 'VICTIM'), (28, 33, 'Part of Human Body'), (16, 22, 'VICTIM'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT FIRED APPROXIMATELY 7 SHOTS AT VICTIM SUSPECT FLED TO EAST COAST CRIPP', {'entities': [(62, 78, 'LOCATION'), (46, 53, 'SUSPECT'), (39, 45, 'VICTIM'), (8, 13, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT DROVE UP IN A VEHICLE SUSPECT1 YELLED OUT FUCK TOAST FLORENCIA AND SHOT APPROXIMATELY 4 SHOTS AT VEHICLE STRICKING VICTIM IN BODY SUSPECT FLED TO A LOCATION 97TH ST EAST COAST CRIP', {'entities': [(156, 188, 'LOCATION'), (146, 150, 'ACTIVITY'), (138, 145, 'SUSPECT'), (133, 137, 'Part of Human Body'), (123, 129, 'VICTIM'), (113, 122, 'ACTIVITY'), (105, 112, 'VEHICLE'), (61, 70, 'LOCATION'), (39, 45, 'ACTIVITY'), (30, 38, 'SUSPECT'), (22, 29, 'VEHICLE'), (8, 13, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT1 AND SUSPECT2 ASSAULTED VICTIM1 AND VICTIM2 WITH BROKEN GLASS BOTTLE VICTIM1 IN CRITICAL CONDITION VICTIM2 HAS LACERATIONS ON HIS NECK', {'entities': [(138, 142, 'Part of Human Body'), (119, 130, 'Injury'), (107, 114, 'VICTIM'), (77, 84, 'VICTIM'), (57, 76, 'OBJECT'), (44, 51, 'VICTIM'), (32, 39, 'VICTIM'), (22, 31, 'ACTIVITY'), (13, 21, 'SUSPECT'), (0, 8, 'SUSPECT')]}), ('SUSPECT 1 AND SUSPECT2 ASSAULTED VICTIM1 AND VICTIM2 WITH BROKEN GLASS BOTTLE VICTIM1 IN CRITICAL CONDITION VICTIM2 HAS LACERATIONS ON HIS NECK', {'entities': [(139, 143, 'Part of Human Body'), (120, 131, 'Injury'), (78, 85, 'VICTIM'), (58, 77, 'OBJECT'), (45, 52, 'VICTIM'), (33, 40, 'VICTIM'), (23, 32, 'ACTIVITY'), (14, 22, 'SUSPECT'), (0, 9, 'SUSPECT')]}), ('SUSPECT1 AND SUSPECT 2 EXITED FROM PARKED VEHICLE AND RAN TO FRONT OF VICTIMS LOCATION SUSPECT1 STATED WHERE YOU FROM SUSPECT1 AND SUSPECT2 FIRED 7 ROUNDS AT VICTIM STRIKING VICTIM 3 TIMES', {'entities': [(174, 180, 'VICTIM'), (165, 173, 'ACTIVITY'), (158, 164, 'VICTIM'), (140, 145, 'ACTIVITY'), (131, 139, 'SUSPECT'), (118, 126, 'SUSPECT'), (96, 102, 'ACTIVITY'), (87, 95, 'SUSPECT'), (78, 86, 'LOCATION'), (70, 77, 'VICTIM'), (54, 57, 'ACTIVITY'), (42, 49, 'VEHICLE'), (23, 29, 'ACTIVITY'), (13, 22, 'SUSPECT'), (0, 8, 'SUSPECT')]}), ('SUSPECT1 WENT TO VICTIM RESIDENT TO CONFRONT HIM REGARDING A PRIOR ALTERCATION WHEN VICTIM STEPPED OUT SUSPECT1 STRUCK HIM WITH A LARGE FLASHLIGHT ON THE HEAD SUSPECT2 BEGAN STRIKING', {'entities': [(174, 182, 'ACTIVITY'), (159, 167, 'SUSPECT'), (154, 158, 'Part of Human Body'), (136, 146, 'OBJECT'), (112, 118, 'ACTIVITY'), (103, 111, 'SUSPECT'), (91, 102, 'ACTIVITY'), (84, 90, 'VICTIM'), (67, 78, 'ACTIVITY'), (24, 32, 'LOCATION'), (17, 23, 'VICTIM'), (0, 8, 'SUSPECT')]}), ('SUSPECT1 PHYSICALLY ASSAULTED VICTIM UNTIL VICTIM WAS LEFT UNCONSCIOUS SUSPECTS FLED IN UNKNOWN DIRECTION IN UNKNOWN VEHICLE', {'entities': [(117, 124, 'VEHICLE'), (80, 84, 'ACTIVITY'), (71, 79, 'SUSPECT'), (43, 49, 'VICTIM'), (30, 36, 'VICTIM'), (20, 29, 'ACTIVITY'), (0, 8, 'SUSPECT')]}), ('SUSPECT1 APPROACHED THE VICTIM AND FIRED A HANDGUN AT THE VICTIM VICTIM WAS STRUCK BY ONE OF THE BULLETS', {'entities': [(97, 104, 'OBJECT'), (76, 82, 'ACTIVITY'), (65, 71, 'VICTIM'), (58, 64, 'VICTIM'), (43, 50, 'OBJECT'), (35, 40, 'ACTIVITY'), (24, 30, 'VICTIM'), (0, 8, 'SUSPECT')]}), ('SUSPECT PUNCHED KICKED AND STRANGLED VICTIM', {'entities': [(37, 43, 'VICTIM'), (27, 36, 'ACTIVITY'), (16, 22, 'ACTIVITY'), (8, 15, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT DROVE UP TO THE VICTIM INFRONT OF HIS BUSINESS AND STATED YOU BITCH DIDNT I TELL YOU TO GET OFF THE BLOCK SUSPECT THEN POINTED A GUN AT THE VICTIM THEN FLED', {'entities': [(160, 164, 'ACTIVITY'), (148, 154, 'VICTIM'), (137, 140, 'OBJECT'), (114, 121, 'SUSPECT'), (59, 65, 'ACTIVITY'), (24, 30, 'VICTIM'), (8, 13, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT APPROACHED VICTIM AND SWING A METAL STEERING WHEEL LOCKING DEVICE AT VICTIM HEAD BARELY MISSING HIM SUSPECT THEN FLED IN VEHICLE FROM SCENE', {'entities': [(129, 136, 'VEHICLE'), (121, 125, 'ACTIVITY'), (108, 115, 'SUSPECT'), (84, 88, 'Part of Human Body'), (77, 83, 'VICTIM'), (38, 73, 'OBJECT'), (30, 35, 'ACTIVITY'), (19, 25, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM GOT INTO ARGUMENT OVER VICTIM RELATIONSHIP WITH CURRENT GIRLFRIEND WHO WAS HIS EXGIRLFRIEND SUSPECT USED KITCHEN KNIFE AND STABBED VICTIM MULTIPLE TIMES IN ABDOMEN', {'entities': [(175, 182, 'Part of Human Body'), (150, 156, 'VICTIM'), (142, 149, 'ACTIVITY'), (124, 137, 'OBJECT'), (111, 118, 'SUSPECT'), (98, 110, 'Relation'), (75, 85, 'Relation'), (49, 61, 'Relationship'), (42, 48, 'VICTIM'), (28, 36, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ENGAGED IN ARGUMENT VICTIM THROWS ALCOHOL BOTTLE AND BOILING WATER AT SUSPECT SUSPECT PUNCHED VICTIM IN FACE LEAVING VISIBLE INJURY', {'entities': [(144, 150, 'Injury'), (123, 127, 'Part of Human Body'), (113, 119, 'VICTIM'), (105, 112, 'ACTIVITY'), (97, 104, 'SUSPECT'), (89, 96, 'SUSPECT'), (72, 85, 'OBJECT'), (53, 67, 'OBJECT'), (46, 52, 'ACTIVITY'), (39, 45, 'VICTIM'), (30, 38, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('SUSPECT AND VICTIM ENGAGE IN ARGUMENT AS VICTIM WALKS AWAY SUSPECT PUSHES VICTIM FROM BEHIND CAUSING VICTIM TO FALL FORWARD INTO GLASS WINDOW VICTIM HAS VISIBLE INJURIES TO BOTH ARMS', {'entities': [(178, 182, 'Part of Human Body'), (161, 169, 'Injury'), (142, 148, 'VICTIM'), (129, 141, 'OBJECT'), (111, 115, 'ACTIVITY'), (101, 107, 'VICTIM'), (74, 80, 'VICTIM'), (67, 73, 'ACTIVITY'), (59, 66, 'SUSPECT'), (41, 47, 'VICTIM'), (29, 37, 'ACTIVITY'), (12, 18, 'VICTIM'), (0, 7, 'SUSPECT')]}), ('UNKNOWN SUSPECT FIRED NUMEROUS ROUNDS AT VICTIM HOUSE FROM A SEMI AUTO PISTOL SUSPECT FLED NBWESLEY ON A MOUNTAIN BIKE', {'entities': [(105, 118, 'VEHICLE'), (91, 99, 'LOCATION'), (86, 90, 'ACTIVITY'), (78, 85, 'SUSPECT'), (61, 77, 'OBJECT'), (48, 53, 'LOCATION'), (41, 47, 'VICTIM'), (16, 21, 'ACTIVITY'), (8, 15, 'SUSPECT')]}), ('SUSPECTS SHOT FROM THEIR VEHICLE INTO AN INHABITED DWELLING AND FLED TO UNKNOWN LOCATION', {'entities': [(80, 88, 'LOCATION'), (64, 68, 'ACTIVITY'), (41, 59, 'LOCATION'), (25, 32, 'VEHICLE'), (9, 13, 'ACTIVITY'), (0, 8, 'SUSPECT')]}), ('VICTIM WALKING DOWN STREET WAS TAKEN DOWN BY A CAR RIDING FAST SUSPECT FLED FAST TO UNKNOWN LOCATION BEGAN TO RUN HEARD ADDITIONAL SHOTS AND REALIZED HE WAS STRUCK" serious', {'entities': [(157, 163, 'ACTIVITY'), (110, 113, 'ACTIVITY'), (92, 100, 'LOCATION'), (71, 75, 'ACTIVITY'), (63, 70, 'SUSPECT'), (51, 57, 'ACTIVITY'), (47, 50, 'VEHICLE'), (7, 14, 'ACTIVITY'), (0, 6, 'VICTIM')]}), ('VICTIM AND SUSPECT ENGAGED IN VERBAL ARGUMENT WHEN SUSPECT ARMED HIMSELF WITH HANDGUN AND POINTED IT TO THE VICTIM HEAD SUSPECT THEN FLED TO LOCATION', {'entities': [(141, 149, 'LOCATION'), (133, 137, 'ACTIVITY'), (120, 127, 'SUSPECT'), (115, 119, 'Part of Human Body'), (108, 114, 'VICTIM'), (90, 97, 'ACTIVITY'), (78, 85, 'OBJECT'), (59, 64, 'ACTIVITY'), (51, 58, 'SUSPECT'), (30, 45, 'ACTIVITY'), (11, 18, 'SUSPECT'), (0, 6, 'VICTIM')]}), ('UNKNOWN SUSPECTS USED UNKNOWN GUN AND FIRED THREE TO SIX SHOTS TOWARDS THE VICTIM STRIKING HIM IN THE HEAD', {'entities': [(102, 106, 'Part of Human Body'), (82, 90, 'ACTIVITY'), (75, 81, 'VICTIM'), (38, 43, 'ACTIVITY'), (22, 33, 'OBJECT'), (8, 16, 'SUSPECT')]}), ('UNKNOWN SUSPECTS SHOT AS VICTIM STRIKING HIM IN BUTTOCKS AREA', {'entities': [(48, 56, 'Part of Human Body'), (32, 40, 'ACTIVITY'), (25, 31, 'VICTIM'), (17, 21, 'ACTIVITY'), (8, 16, 'SUSPECT')]}), ('UNKNOWN SUSPECT APPROACHED VICTIM FROM BEHIND AND STRUCK VICTIM ON BACK OF HEAD WITH GLASS CUP AND FLED TO UNKNOWN LOCATION', {'entities': [(115, 123, 'LOCATION'), (99, 103, 'ACTIVITY'), (85, 94, 'OBJECT'), (75, 79, 'Part of Human Body'), (57, 63, 'VICTIM'), (50, 56, 'ACTIVITY'), (27, 33, 'VICTIM'), (8, 15, 'SUSPECT')]}), ('SUSPECTS AND VICTIM EXCHANGE WORDS SUSPECT1 FIRED APPROXIMATELY 10 SHOTS AT VICTIM SUSPECTS FLED', {'entities': [(92, 96, 'ACTIVITY'), (83, 91, 'SUSPECT'), (76, 82, 'VICTIM'), (44, 49, 'ACTIVITY'), (35, 43, 'SUSPECT'), (20, 34, 'ACTIVITY'), (13, 19, 'VICTIM'), (0, 8, 'SUSPECT')]}), ('SUSPECT RAMMED VEHICLE INTO REAR END OF VICTIMS VEHICLE', {'entities': [(48, 55, 'VEHICLE'), (40, 47, 'VICTIM'), (15, 22, 'VEHICLE'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]}), ('SUSPECT PULLED VICTIM OF A COUCH AND STRUCK HIM ON THE HEAD WITH A BOTTLE', {'entities': [(67, 73, 'OBJECT'), (55, 59, 'Part of Human Body'), (37, 43, 'ACTIVITY'), (27, 32, 'OBJECT'), (15, 21, 'VICTIM'), (8, 14, 'ACTIVITY'), (0, 7, 'SUSPECT')]})]

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
disable_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
with nlp.disable_pipes(*disable_pipes):
    optimizer = nlp.resume_training()
    
    for iteration in range(30):
        random.shuffle(train_data)
        losses = {}
        
        batches = minibatch(train_data, size=compounding(1.0,4.0,1.001))
        for batch in batches:
            text,annotation = zip(*batch)
            nlp.update(
                       text,
                       annotation,
                       drop=0.5,
                       losses=losses,
                       sgd=optimizer
                      )
            print("LOSSES",losses)
# Out:
# LOSSES {'ner': 23.586204886436462}
# LOSSES {'ner': 40.226341009140015}
# LOSSES {'ner': 63.654441356658936}
# LOSSES {'ner': 69.50783061981201}
# LOSSES {'ner': 88.71808791160583}
# LOSSES {'ner': 108.64978766441345}
# LOSSES {'ner': 117.02470988035202}
# LOSSES {'ner': 146.83513510227203}
# LOSSES {'ner': 172.66028052568436}
# LOSSES {'ner': 186.75546544790268}
# LOSSES {'ner': 204.5109485387802}
# LOSSES {'ner': 231.24570700526237}
# LOSSES {'ner': 242.005618840456}
# LOSSES {'ner': 258.59538158774376}
# LOSSES {'ner': 276.26904789730906}
# LOSSES {'ner': 293.5457496456802}
# LOSSES {'ner': 311.53378346934915}
# LOSSES {'ner': 333.64033813402057}
# LOSSES {'ner': 349.22192926332355}
# LOSSES {'ner': 358.2202955149114}
# LOSSES {'ner': 372.90771594271064}
# LOSSES {'ner': 389.6134951226413}
# LOSSES {'ner': 401.05532728601247}
# LOSSES {'ner': 426.94493765896186}
# LOSSES {'ner': 442.4403211851604}
# LOSSES {'ner': 455.44872878910974}
# LOSSES {'ner': 470.409804915078}
# ...

# %%
for text, _ in train_data:
    doc = nlp(text)
    print('Entities',[(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('SUSPECT', 'SUSPECT'), ('VICTIM', 'VICTIM'), ('VERBAL DISPUTE', 'ACTIVITY'), ('SUSPECT', 'SUSPECT'), ('PUSHED', 'ACTIVITY'), ('VICTIM', 'VICTIM'), ('PUNCHED', 'ACTIVITY'), ('VICTIM', 'VICTIM'), ('RIGHT', 'Part of Human Body'), ('CLOSED FIST', 'Part of Human Body')]
# Entities [('SUSPECT', 'SUSPECT'), ('VICTIM', 'VICTIM'), ('DISPUTE', 'ACTIVITY'), ('SUSPECT', 'SUSPECT'), ('ENRAGED', 'SENTIMENT'), ('STRUCK', 'ACTIVITY'), ('VICTIM', 'VICTIM'), ('FACE', 'Part of Human Body')]
# Entities [('SUSPECT', 'SUSPECT'), ('VICTIM', 'VICTIM'), ('VERBAL DISPUTE', 'ACTIVITY'), ('SUSPECT', 'SUSPECT'), ('PUSHED', 'ACTIVITY'), ('VICTIM', 'VICTIM'), ('PUNCHED', 'ACTIVITY'), ('VICTIM', 'VICTIM'), ('RIGHT CHEEK', 'Part of Human Body'), ('CLOSED FIST', 'Part of Human Body')]
# ...

# %%
Entity_list1 = []
Entity_list2 = []
for text, _ in train_data:
    for ent in doc.ents:
        doc = nlp(text)
        Entity_list1.append(ent.text)
        Entity_list2.append(ent.label_)

# %%
Entity = pd.DataFrame({'Entity':Entity_list1,
                       'Entity_Name':Entity_list2})

# %%
Entity.head(20)
# Out:
#             Entity         Entity_Name
# 0          SUSPECT             SUSPECT
# 1          PUNCHED            ACTIVITY
# 2           KICKED            ACTIVITY
# 3        STRANGLED            ACTIVITY
# 4           VICTIM              VICTIM
# 5          SUSPECT             SUSPECT
# 6           VICTIM              VICTIM
# 7   VERBAL DISPUTE            ACTIVITY
# 8          SUSPECT             SUSPECT
# 9           PUSHED            ACTIVITY
# 10          VICTIM              VICTIM
# 11         PUNCHED            ACTIVITY
# 12          VICTIM              VICTIM
# 13           RIGHT  Part of Human Body
# 14     CLOSED FIST  Part of Human Body
# 15         SUSPECT             SUSPECT
# 16          VICTIM              VICTIM
# 17         DISPUTE            ACTIVITY
# 18         SUSPECT             SUSPECT
# 19         ENRAGED           SENTIMENT

# %%
output_dir=Path("/home/rebel/Documents/ner")

# %%
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)
# Out:
# Saved model to /home/rebel/Documents/ner

# %%
model = spacy.load('/home/rebel/Documents/ner')

# %%
Test_list1 = []
Test_list2 = []
doc = nlp("SUSPECT AND VICTIM INVOLVED in FIGHTING")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# SUSPECT 0 7 SUSPECT
# VICTIM 12 18 VICTIM
# FIGHTING 31 39 ACTIVITY
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SUSPECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SUSPECT</span>
# </mark>
#  AND
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VICTIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">VICTIM</span>
# </mark>
#  INVOLVED in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
doc = nlp("SUSPECT AND VICTIM ENGAGED IN DISPUTE SUSPECT BECAME ENRAGED AND STRUCK VICTIM IN THE FACE")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# SUSPECT 0 7 SUSPECT
# VICTIM 12 18 VICTIM
# DISPUTE 30 37 ACTIVITY
# SUSPECT 38 45 SUSPECT
# ENRAGED 53 60 SENTIMENT
# STRUCK 65 71 ACTIVITY
# VICTIM 72 78 VICTIM
# FACE 86 90 Part of Human Body
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SUSPECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SUSPECT</span>
# </mark>
#  AND
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VICTIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">VICTIM</span>
# </mark>
#  ENGAGED IN
# ...

# %%
doc = nlp("INCIDENT TO ARREST SUSPECT KICKED OFFICER IN THE TORSO")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# ARREST 12 18 ACTIVITY
# SUSPECT 19 26 SUSPECT
# KICKED 27 33 ACTIVITY
# TORSO 49 54 Part of Human Body
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">INCIDENT TO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARREST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SUSPECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SUSPECT</span>
# </mark>
#
# ...

# %%
doc = nlp("UNKNOWN SUSPECT CAUSED CONFUSION AND LACERATION TO THE BACK OF VICTIMS HEAD BY UNKNOWN MEANS")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# SUSPECT 8 15 SUSPECT
# LACERATION 37 47 LOCATION
# VICTIMS 63 70 VICTIM
# HEAD 71 75 Part of Human Body
# MEANS 87 92 OBJECT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">UNKNOWN
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SUSPECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SUSPECT</span>
# </mark>
#  CAUSED CONFUSION AND
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LACERATION
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOCATION</span>
# </mark>
#  TO THE BACK OF
# ...

# %%
doc = nlp("SUSPECT CHALLENGED VICTIM TO A FIGHT AND THEN THREW A CANDY BAR AT VICTIMS FACE CAUSING AN ABRASION TO VICTIMS MOUTH")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# SUSPECT 0 7 SUSPECT
# VICTIM 19 25 VICTIM
# FIGHT 31 36 Part of Human Body
# BAR 60 63 OBJECT
# VICTIMS 67 74 VICTIM
# FACE 75 79 Part of Human Body
# ABRASION 91 99 LOCATION
# VICTIMS 103 110 VICTIM
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SUSPECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SUSPECT</span>
# </mark>
#  CHALLENGED
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VICTIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">VICTIM</span>
# </mark>
#  TO A
# ...

# %%
Test.head(20)
# Out:
#         Entity         Entity_Name
# 0      SUSPECT             SUSPECT
# 1       VICTIM              VICTIM
# 2     FIGHTING            ACTIVITY
# 3      SUSPECT             SUSPECT
# 4       VICTIM              VICTIM
# 5      DISPUTE            ACTIVITY
# 6      SUSPECT             SUSPECT
# 7      ENRAGED           SENTIMENT
# 8       STRUCK            ACTIVITY
# 9       VICTIM              VICTIM
# 10        FACE  Part of Human Body
# 11      ARREST            ACTIVITY
# 12     SUSPECT             SUSPECT
# 13      KICKED            ACTIVITY
# 14       TORSO  Part of Human Body
# 15     SUSPECT             SUSPECT
# 16  LACERATION            LOCATION
# 17     VICTIMS              VICTIM
# 18        HEAD  Part of Human Body
# 19       MEANS              OBJECT
