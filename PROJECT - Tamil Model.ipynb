# %%
import pandas as pd
import string
import random
from pathlib import Path
import csv
import spacy
from spacy import displacy
from spacy.util import minibatch,compounding

# %%
data=pd.read_csv("/home/rebel/tamildata.txt")

# %%
data.shape
# Out:
# (98, 1)

# %%
data.head(5)
# Out:
#                                                 News
# 0  தடை செய்யப்பட்ட 3 நம்பர் லாட்டரி விற்பனை... மு...
# 1  சத்தியமங்கலம்: சட்ட விரோத மின் வேலியில் சிக்கி...
# 2  திண்டுக்கல்: நிதி நிறுவனம் நடத்தி ரூ.40 கோடி ம...
# 3  மதுரையில் 16 வயது சிறுமிக்கு நடந்த கொடூரம் - ப...
# 4  சென்னை காப்பகத்தில் பெங்களூர் சிறுமிக்கு பாலிய...

# %%
data.dropna(axis=1)
data.head(5)
# Out:
#                                                 News
# 0  தடை செய்யப்பட்ட 3 நம்பர் லாட்டரி விற்பனை... மு...
# 1  சத்தியமங்கலம்: சட்ட விரோத மின் வேலியில் சிக்கி...
# 2  திண்டுக்கல்: நிதி நிறுவனம் நடத்தி ரூ.40 கோடி ம...
# 3  மதுரையில் 16 வயது சிறுமிக்கு நடந்த கொடூரம் - ப...
# 4  சென்னை காப்பகத்தில் பெங்களூர் சிறுமிக்கு பாலிய...

# %%
punct = '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{}~'   # `|` is not present here
transtab = str.maketrans(dict.fromkeys(punct, ''))

data['News'] = '|'.join(data['News'].tolist()).translate(transtab).split('|')

# %%
data["News"][1]
# Out:
# 'சத்தியமங்கலம் சட்ட விரோத மின் வேலியில் சிக்கி உயிரிழந்த ஆண் யானை  தோட்ட உரிமையாளர் கைது'

# %%
data.to_csv(r'/home/rebel/Documents/tamilnew.csv', index = False)

# %%
csv_file = input('Enter the name of your input file: ')
txt_file = input('Enter the name of your output file: ')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# Enter the name of your input file: /home/rebel/Documents/tamilnew.csv
# Enter the name of your output file: /home/rebel/Documents/Tamildata.txt

# %% [markdown]
# # WORKING WITH NER

# %%
nlp=spacy.blank("xx")

nlp.add_pipe(nlp.create_pipe('ner'))

nlp.begin_training()
# Out:
# /home/rebel/.local/lib/python3.8/site-packages/spacy/language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(

# %%
nlp.pipe_names
# Out:
# ['ner']

# %%
train_data = [('தடை செய்யப்பட்ட 3 நம்பர் லாட்டரி விற்பனை... முதலாளி உள்ளிட்ட 2 பேர் கைது', {'entities': [(68, 72, 'Activity'), (61, 62, 'Numeric'), (44, 51, 'Profession'), (33, 40, 'Activity'), (25, 32, 'Object'), (18, 24, 'Numeric'), (16, 17, 'Numeric'), (0, 3, 'Restricted')]}), ('சத்தியமங்கலம் சட்ட விரோத மின் வேலியில் சிக்கி உயிரிழந்த ஆண் யானை தோட்ட உரிமையாளர் கைது', {'entities': [(82, 86, 'Activity'), (71, 81, 'Profession'), (60, 64, 'Animals'), (56, 59, 'Sex'), (25, 38, 'Object'), (14, 24, 'Restricted'), (0, 13, 'Location')]}), ('திண்டுக்கல் நிதி நிறுவனம் நடத்தி ரூ.40 கோடி மோசடி தம்பதி உட்பட 3 பேர் கைது', {'entities': [(63, 64, 'Numeric'), (50, 56, 'Relation'), (44, 49, 'Crime'), (33, 43, 'Money'), (12, 25, 'Organization'), (0, 11, 'Location')]}), ('மதுரையில் 16 வயது சிறுமிக்கு நடந்த கொடூரம் பாலியல் தொழிலில் ஈடுபடுத்திய பெண்கள் கைது', {'entities': [(80, 84, 'Activity'), (72, 79, 'Sex'), (60, 71, 'Activity'), (43, 59, 'Crime'), (35, 42, 'Activity'), (18, 28, 'Relation'), (13, 17, 'Age'), (10, 12, 'Numeric'), (0, 9, 'Location')]}), ('சென்னை காப்பகத்தில் பெங்களூர் சிறுமிக்கு பாலியல் தொல்லை வாட்ச்மேனால் நேர்ந்த கொடூரம்', {'entities': [(77, 84, 'Activity'), (56, 68, 'Suspect'), (41, 55, 'Crime'), (30, 40, 'Victim'), (20, 29, 'Location'), (7, 19, 'Location'), (0, 6, 'Location')]}), ('பெங்களூரு லோன் ஆப் மூலம் கடன் பெற்றவருக்கு மிரட்டல் போலீஸ் வழக்குப்பதிவு', {'entities': [(59, 72, 'Crime'), (52, 58, 'Public Officer'), (43, 51, 'Activity'), (10, 14, 'Money'), (0, 9, 'Location')]}), ('ஆக்கிரமிப்பை அகற்றிய போலீஸ் முகத்தில் கொதிக்கும் தேநீரை ஊற்றியப் பெண் பீகார் அதிர்ச்சி', {'entities': [(65, 69, 'Sex'), (56, 64, 'Activity'), (38, 55, 'Object'), (21, 27, 'Public Officer'), (0, 12, 'Activity')]}), ('விருதுநகர் போக்சோ வழக்கில் தேடப்பட்ட நபர் தூக்கில் தொங்கிய நிலையில் சடலமாக மீட்பு', {'entities': [(75, 81, 'Activity'), (51, 58, 'Activity'), (37, 41, 'Suspect'), (27, 36, 'Activity'), (11, 26, 'Crime'), (0, 10, 'Location')]}), ('1 கோடி மதிப்பிலான 863 செல்போன்களை மீட்ட சென்னை காவல்துறை 3 மாதங்களில் அதிரடி நடவடிக்கை', {'entities': [(77, 86, 'Activity'), (59, 69, 'Month'), (57, 58, 'Numeric'), (47, 56, 'Public Officer'), (40, 46, 'Location'), (34, 39, 'Activity'), (22, 33, 'Object'), (18, 21, 'Numeric'), (0, 6, 'Money')]}), ('அறுவை சிகிச்சைக்கு வந்த பெண்ணுக்கு பாலியல் தொல்லை கொடுத்த வார்டுபாய் மும்பை அதிர்ச்சி', {'entities': [(69, 75, 'Location'), (58, 68, 'Suspect'), (35, 49, 'Crime'), (24, 34, 'Victim'), (0, 18, 'Medical Treatment')]}), ('கேரள கன்னியாஸ்திரி கொலை வழக்கில் உயர்ந்த மனிதனாக நிற்கும் ’திருடன்’ நெகிழ வைத்த சாட்சியம்', {'entities': [(80, 89, 'Activity'), (68, 73, 'Object'), (59, 66, 'Suspect'), (19, 23, 'Crime'), (5, 18, 'Relation'), (0, 4, 'Location')]}), ('சேலத்தில் ரவுடி வெட்டிக் கொலை பின்னணியில் ரேஷன் பொருள் கடத்தல் சம்பவம்', {'entities': [(63, 70, 'Crime'), (55, 62, 'Crime'), (48, 54, 'Object'), (42, 47, 'Organization'), (25, 29, 'Crime'), (16, 24, 'Activity'), (10, 15, 'Profession'), (0, 9, 'Location')]}), ('காவல்துறையை பழிவாங்க ஸ்கெட்ச் ஒரு சைக்கிள் திருடனின் மறுபக்கம்', {'entities': [(43, 52, 'Crime'), (34, 42, 'Object'), (21, 29, 'Activity'), (12, 20, 'Activity'), (0, 11, 'Public Officer')]}), ('ஆன் லைன் ஆப் மூலம் ரூ.4000 கடன் நிறுவனம் கொடுத்த நெருக்கடியால் இளைஞர் தற்கொலை', {'entities': [(70, 77, 'Crime'), (63, 69, 'Sex'), (49, 62, 'Activity'), (41, 48, 'Activity'), (32, 40, 'Organization'), (19, 26, 'Money'), (9, 12, 'Object')]}), ('காதல் திருமணம் நடத்தையில் சந்தேகம் விவாகரத்து கோரியதால் மனைவியை வெட்டிக்கொன்ற கணவர்', {'entities': [(78, 83, 'Suspect'), (64, 77, 'Crime'), (56, 63, 'Victim'), (35, 45, 'Activity'), (15, 25, 'Activity'), (0, 5, 'Relation')]}), ('சுரேஷ் ரெய்னா கைதாகி ஜாமீனில் விடுதலை', {'entities': [(30, 37, 'Activity'), (14, 20, 'Activity'), (0, 13, 'Person Name')]}), ('அபயா கொலையில் இருவர் குற்றவாளிகள் கேரளாவை உலுக்கிய வழக்கில் 28 ஆண்டுகளுக்கு பின் தீர்ப்பு', {'entities': [(81, 89, 'Activity'), (63, 75, 'Year'), (60, 62, 'Numeric'), (42, 50, 'Activity'), (34, 41, 'Location'), (21, 33, 'Suspect'), (14, 20, 'Numeric'), (5, 13, 'Crime'), (0, 4, 'Person Name')]}), ('உ.பி 13 வயது சிறுமிக்கு நேர்ந்த கொடூரம் போலீஸ் விசாரணை', {'entities': [(47, 54, 'Activity'), (40, 46, 'Public Officer'), (32, 39, 'Crime'), (24, 31, 'Activity'), (13, 23, 'Victim'), (8, 12, 'Age'), (5, 7, 'Numeric'), (0, 4, 'Location')]}), ('நீரவ் மோடி செய்ததை விட பெரியது... செருகுரி ஸ்ரீதர் செய்த ரூ.7296 கோடி நிதி மோசடி', {'entities': [(75, 80, 'Crime'), (70, 74, 'Money'), (57, 69, 'Money'), (34, 50, 'Person Name'), (11, 18, 'Activity'), (0, 10, 'Person Name')]}), ('துபாய் டூ சென்னை விமானத்தில் கடத்தி வரப்பட்ட சிறுத்தை பற்கள்', {'entities': [(54, 60, 'Object'), (45, 53, 'Animals'), (36, 44, 'Activity'), (29, 35, 'Crime'), (17, 28, 'Organization'), (10, 16, 'Location'), (0, 6, 'Location')]}), ('புற்றுநோய் இருப்பதாக கூறி 1.47 கோடி ஏமாற்றிவிட்டார்’ மருத்துவர் மீது பெண் புகார்', {'entities': [(74, 80, 'Activity'), (69, 73, 'Sex'), (53, 63, 'Suspect'), (36, 51, 'Crime'), (26, 35, 'Money'), (21, 25, 'Activity'), (0, 10, 'Medical Treatment')]}), ('ரூ19 கோடி மதிப்பிலான வைரங்கள் மோசடி நிரவ் மோடியின் சகோதரர் மீது குற்றச்சாட்டு', {'entities': [(64, 77, 'Activity'), (51, 58, 'Relation'), (36, 50, 'Person Name'), (30, 35, 'Crime'), (21, 29, 'Object'), (0, 9, 'Money')]}), ('எனது வாட்ஸ்அப் இனி இயங்காது கொலையாவதற்கு முன் மாற்றுத்திறனாளி பெண் அனுப்பிய இறுதி மெசேஜ்', {'entities': [(82, 88, 'Activity'), (62, 66, 'Sex'), (46, 61, 'Handicapped'), (28, 40, 'Crime'), (19, 27, 'Activity'), (5, 14, 'Organization')]}), ('மதுரை மென்பொறியாளர் கொலையில் வடமாநில நபர் தொடர்பா போலீஸ் விசாரணை', {'entities': [(57, 64, 'Activity'), (50, 56, 'Public Officer'), (29, 36, 'Location'), (20, 28, 'Crime'), (6, 19, 'Profession'), (0, 5, 'Location')]}), ('மதுரை சிறுமிக்கு திருமண ஆசைகாட்டி ஏமாற்றிய வாலிபர் போக்சோ சட்டத்தில் கைது', {'entities': [(69, 73, 'Activity'), (51, 68, 'Crime'), (43, 50, 'Suspect'), (6, 16, 'Sex'), (0, 5, 'Location')]}), ('சாப்பிட்ட உணவுக்கு பில் கேட்ட ஊழியர்களிடம் போதையில் தகராறு செய்த சப்இன்ஸ்பெக்டர்', {'entities': [(65, 80, 'Public Officer'), (52, 58, 'Crime'), (30, 42, 'Profession'), (19, 23, 'Object'), (10, 18, 'Object'), (0, 9, 'Activity')]}), ('103 கிலோ தங்கம் காணாமல்போன வழக்கு முன்னாள் டிஜிபியிடம் விசாரிக்க சிபிஐ திட்டம்', {'entities': [(65, 70, 'Public Officer'), (55, 64, 'Activity'), (43, 54, 'Public Officer'), (9, 15, 'Object'), (0, 3, 'Numeric')]}), ('காட்பாடி நடந்து சென்ற பெண்ணை கீழே தள்ளி கழுத்திலிருந்த தங்க நகை பறிப்பு வீடியோ', {'entities': [(64, 71, 'Crime'), (55, 63, 'Object'), (40, 54, 'Part of human body'), (34, 39, 'Activity'), (22, 28, 'Victim'), (16, 21, 'Activity'), (0, 8, 'Location')]}), ('துண்டு துண்டாக சூட்கேஸில் சடலம் அலுவலக தோழியை பார்க்க சென்றவருக்கு நேர்ந்த விபரீதம்', {'entities': [(75, 83, 'Crime'), (67, 74, 'Activity'), (54, 66, 'Victim'), (32, 45, 'Profession'), (15, 25, 'Object')]}), ('லஞ்சத்த கையில கொடுக்காதீங்க.. பின்பாக்கெட்ல வைங்க வீடியோவால் சிக்கிக் கொண்ட பெண் காவலர்', {'entities': [(81, 87, 'Public Officer'), (76, 80, 'Sex'), (50, 60, 'Object'), (44, 49, 'Activity'), (0, 7, 'Money')]}), ('கூட்டுப்பாலியல் வன்கொடுமை ஹத்ராஸ் வழக்கில் குற்றப்பத்திரிகை தாக்கல் செய்தது சிபிஐ', {'entities': [(76, 81, 'Public Officer'), (43, 59, 'Object'), (16, 25, 'Crime'), (0, 15, 'Crime')]}), ('பீகார் கால்நடை திருட்டு சந்தேகம் இளைஞரை அடித்துக்கொன்ற கும்பல்', {'entities': [(40, 54, 'Crime'), (24, 39, 'Suspect'), (15, 23, 'Crime'), (7, 14, 'Animals'), (0, 6, 'Location')]}), ('4 வயது சிறுமிக்கு பாலியல் வன்கொடுமை தனியார் பள்ளி வாகன ஓட்டுநர் உதவியாளருக்கு..', {'entities': [(50, 63, 'Suspect'), (36, 49, 'Organization'), (18, 35, 'Crime'), (7, 17, 'Victim'), (2, 6, 'Age'), (0, 1, 'Numeric')]}), ('விதிகளை மீறி நைட் கிளப் கொண்டாட்டம் சுரேஷ் ரெய்னா உட்பட 34 பேர் கைது', {'entities': [(64, 68, 'Activity'), (56, 58, 'Numeric'), (36, 49, 'Person Name'), (24, 35, 'Activity'), (13, 23, 'Organization')]}), ('மருத்துவப் படிப்புக்கு சீட் வாங்கித் தருவதாகப் பண மோசடி பாமக முன்னாள் நகரச்...', {'entities': [(56, 60, 'Organization'), (50, 55, 'Crime'), (47, 49, 'Money'), (37, 46, 'Activity'), (28, 36, 'Activity'), (23, 27, 'Object')]}), ('முகநூலில் அறிமுகமான சிறுமியை திருமணம் செய்வதாக கூறி கடத்திய இளைஞர் கைது போக்சோ...', {'entities': [(72, 81, 'Crime'), (60, 66, 'Suspect'), (52, 59, 'Crime'), (20, 28, 'Victim')]}), ('மதுரையில் லஞ்ச வழக்கில் சிறை தண்டனை பெற்ற காவல் ஆய்வாளர் மனைவியைக் கொன்று...', {'entities': [(67, 73, 'Crime'), (57, 66, 'Relation'), (42, 56, 'Public Officer'), (24, 35, 'Crime'), (10, 14, 'Money'), (0, 9, 'Location')]}), ('பட்டா பெயர் மாற்றம் செய்ய ரூ.2500 லஞ்சம் வாங்கிய விஏஓ கைது', {'entities': [(54, 58, 'Activity'), (49, 53, 'Profession'), (41, 48, 'Activity'), (26, 40, 'Money'), (12, 25, 'Activity')]}), ('தமிழகத்தில் 7 ஐபிஎஸ் அதிகாரிகள் திடீர் இடமாற்றம்', {'entities': [(39, 48, 'Activity'), (14, 31, 'Profession'), (12, 13, 'Numeric'), (0, 11, 'Location')]}), ('சித்ரா தற்கொலை வழக்கு ஹேம்நாத் கைது பின்னணி என்ன', {'entities': [(31, 35, 'Crime'), (22, 30, 'Person Name'), (7, 14, 'Crime'), (0, 6, 'Person Name')]}), ('தேனியில் கர்ப்பிணி மனைவியைக் கொன்ற கணவருக்கு மரண தண்டனை நீதிமன்றம் தீர்ப்பு', {'entities': [(67, 75, 'Activity'), (45, 55, 'Activity'), (35, 44, 'Suspect'), (29, 34, 'Crime'), (9, 28, 'Victim'), (0, 8, 'Location')]}), ('சோளிங்கர் ஸ்ரீ யோக லட்சுமி நரசிம்மசுவாமி கோயில் குளத்தில் குளிக்கச் சென்ற 2...', {'entities': [(77, 78, 'Numeric'), (61, 70, 'Activity'), (51, 60, 'Location'), (43, 50, 'Organization'), (16, 42, 'Person Name'), (11, 15, 'Sex'), (0, 10, 'Location')]}), ('ஆ.ராசா மீது திடீர் வழக்குப்பதிவு முதல்வருக்கு எதிராக அவதூறாக பேசியதாக புகார்', {'entities': [(53, 69, 'Activity'), (19, 32, 'Activity'), (0, 6, 'Person Name')]}), ('ஒப்பந்தப் பணியாளருக்கு பாலியல் தொந்தரவு மதுரை மாநகராட்சி சுகாதார ஆய்வாளர் மீது வழக்கு', {'entities': [(79, 85, 'Activity'), (57, 73, 'Suspect'), (46, 56, 'Organization'), (40, 45, 'Location'), (23, 39, 'Crime'), (10, 22, 'Victim')]}), ('மதுரை அருகே தனியார் பேருந்து மோதி ஆட்டோவில் பயணித்த இருவர் பலி', {'entities': [(59, 62, 'Activity'), (52, 58, 'Numeric'), (34, 43, 'Vehicle'), (12, 28, 'Vehicle'), (0, 5, 'Location')]}), ('காரைக்குடி அருகே குழந்தையைக் கடத்தி நாடகமாடிய பாட்டி துரிதமாக செயல்பட்டு மீட்ட போலீஸார்', {'entities': [(79, 87, 'Public Officer'), (73, 78, 'Activity'), (62, 72, 'Activity'), (46, 52, 'Suspect'), (29, 35, 'Activity'), (17, 28, 'Victim'), (0, 10, 'Location')]}), ('சிவகங்கையில் முதல்வர் நிகழ்ச்சிக்கு பெற்றோர் சென்றுவிட எதிர்பாராமல் விபத்தில் இறந்த 4 வயது...', {'entities': [(86, 93, 'Age'), (84, 85, 'Numeric'), (45, 54, 'Activity'), (36, 44, 'Relation'), (13, 21, 'Profession'), (0, 12, 'Location')]}), ('கேரளாவில் நாயை காரில் கட்டி இழுத்து சென்ற நபர் கைது..', {'entities': [(47, 51, 'Activity'), (42, 46, 'Suspect'), (28, 35, 'Activity'), (15, 21, 'Vehicle'), (10, 14, 'Animals'), (0, 9, 'Location')]}), ('பிறந்த குழந்தை தம்பியின் ஜாடையில் இருந்ததால் கொலை செய்த தந்தை.. ஈரோட்டில் அதிர்ச்சி', {'entities': [(64, 73, 'Location'), (56, 61, 'Suspect'), (50, 55, 'Activity'), (45, 49, 'Crime'), (15, 24, 'Relation')]}), ('தங்கையுடன் குடும்பம் நடத்தி வந்த வாலிபர் ஓட ஓட வெட்டிக்கொலை.. நெல்லை பயங்கரம்', {'entities': [(62, 68, 'Location'), (47, 59, 'Crime'), (44, 46, 'Activity'), (41, 43, 'Activity'), (21, 32, 'Activity')]}), ('கருப்பு சட்டை எதிர் வீட்டு வாலிபர் ஈர்ப்பு', {'entities': [(35, 42, 'Activity'), (20, 26, 'Organization'), (0, 13, 'Object')]}), ('சித்ராவின் மரணத்தை குறித்து ஹேமந்த் கூறிய முக்கிய தகவல்', {'entities': [(36, 41, 'Activity'), (28, 35, 'Person Name'), (11, 18, 'Crime'), (0, 10, 'Person Name')]}), ('ஏழு வருட வேதனை 14 வயதில் தொடங்கிய பலாத்காரம்', {'entities': [(34, 44, 'Crime'), (25, 33, 'Activity'), (18, 24, 'Age'), (15, 17, 'Numeric'), (4, 8, 'Year'), (0, 3, 'Numeric')]}), ('மீனாட்சி அம்மன் கோயிலில் பெரும்பாலானவர்கள் போலி களையெடுக்கும் பணி தீவிரம்', {'entities': [(62, 65, 'Activity'), (43, 61, 'Crime'), (16, 24, 'Organization'), (0, 15, 'Person Name')]}), ('மனைவிக்கு பயந்து விடுப்பு விண்ணப்பம் அளித்த காவலர்.. வித்தியாச பின்குறிப்பு', {'entities': [(63, 75, 'Activity'), (44, 50, 'Public Officer'), (37, 43, 'Activity'), (0, 9, 'Relation')]}), ('கனிமொழி பிரச்சாரத்தில் லட்ச ரூபாய்க்கு மேல் பிக்பாக்கெட் 3பேர்தான் இதைச் செய்தது', {'entities': [(73, 80, 'Activity'), (58, 66, 'Sex'), (57, 58, 'Numeric'), (44, 56, 'Crime'), (23, 38, 'Money'), (8, 22, 'Activity'), (0, 7, 'Person Name')]}), ('திருப்பத்தூரில் கணவன் பிள்ளைகளை பெட்ரோல் ஊற்றி எரித்த மனைவி..', {'entities': [(54, 59, 'Suspect'), (47, 53, 'Crime'), (41, 46, 'Activity'), (32, 40, 'Object'), (22, 31, 'Victim'), (16, 21, 'Victim'), (0, 15, 'Location')]}), ('சித்ரா முகத்தில் இருந்த நக கீறல் யாருடையது பிரேத பரிசோதனை வெளியானது...', {'entities': [(58, 67, 'Activity'), (49, 57, 'Activity'), (24, 26, 'Object'), (7, 16, 'Part of human body'), (0, 6, 'Person Name')]}), ('20 முறை பறந்த துப்பாக்கி குண்டுகள் மாயமான தங்க நகைகள் திக் திக் நிமிடங்கள்', {'entities': [(64, 74, 'Time'), (42, 53, 'Object'), (25, 34, 'Object'), (14, 24, 'Object'), (0, 2, 'Numeric')]}), ('அசிங்கமா இருக்கு கதறும் சூர்யாவின் டிக்டாக் ஜோடி ரவுடி பேபிக்கு நடந்தது என்ன', {'entities': [(49, 54, 'Person Name'), (44, 48, 'Relation'), (35, 43, 'Organization'), (24, 34, 'Person Name'), (17, 23, 'Activity')]}), ('மசாஜ் சென்டரில் மஜா டிக்டாக் புகழ் ரவுடி பேபி சூர்யா கைது', {'entities': [(46, 52, 'Person Name'), (35, 40, 'Person Name'), (29, 34, 'Activity'), (20, 28, 'Organization'), (0, 15, 'Organization')]}), ('விருந்தில் சாப்பிட்ட தலித் இளைஞர் அடித்துக் கொலை', {'entities': [(44, 48, 'Crime'), (34, 43, 'Activity'), (27, 33, 'Sex'), (21, 26, 'Activity'), (11, 20, 'Activity')]}), ('சித்ரா கன்னத்தில் இரத்தக் கறை மரணத்தின் பின்னுள்ள மர்மம் என்ன', {'entities': [(50, 56, 'Crime'), (30, 39, 'Crime'), (26, 29, 'Object'), (7, 17, 'Part of human body'), (0, 6, 'Person Name')]}), ('சென்னையில் நடந்து சென்ற கர்ப்பிணி மீது கார் மோதி பலி அரசு பெண் அதிகாரி தப்பியோட்டம்', {'entities': [(71, 83, 'Activity'), (63, 70, 'Public Officer'), (58, 62, 'Sex'), (53, 57, 'Organization'), (49, 52, 'Crime'), (44, 48, 'Activity'), (39, 43, 'Vehicle'), (24, 33, 'Sex'), (18, 23, 'Activity'), (11, 17, 'Activity'), (0, 10, 'Location')]}), ('அவதூறு வழக்கில் கைதான ஓய்வு பெற்ற நீதிபதி கர்ணனுக்கு உடல்நலக் குறைவு', {'entities': [(53, 68, 'Medical Treatment'), (42, 52, 'Person Name'), (34, 41, 'Public Officer'), (16, 21, 'Activity'), (0, 15, 'Crime')]}), ('வாலிபரை படுகொலை செய்த மர்மக் கும்பலுக்கு போலீசார் வலைவீச்சு', {'entities': [(50, 59, 'Activity'), (41, 49, 'Public Officer'), (22, 40, 'Suspect'), (16, 21, 'Activity'), (8, 15, 'Crime'), (0, 7, 'Sex')]}), ('செல்போனில் PUBG விளையாடிய சிறுவன் மாரடைப்பால் உயிரிழப்பு', {'entities': [(34, 45, 'Medical Treatment'), (26, 33, 'Sex'), (16, 25, 'Activity'), (11, 15, 'Organization'), (0, 10, 'Object')]}), ('தலைக்கேறிய போதை.. நிலைதடுமாறி நீரில் விழுந்து ஒருவர் பலி..', {'entities': [(46, 52, 'Sex'), (37, 45, 'Activity'), (18, 29, 'Activity'), (11, 15, 'Crime')]}), ('தந்தை உலக்கையால் அடித்து கொலை.. மாத்திரை சாப்பிட சொன்னதால் மகன் ஆத்திரம்..', {'entities': [(59, 63, 'Suspect'), (49, 58, 'Activity'), (41, 48, 'Activity'), (25, 29, 'Crime'), (17, 24, 'Activity'), (0, 5, 'Relation')]}), ('இந்திய பெண் ஒருவர் கொலை வழக்கில் துப்பு கொடுத்தால் தக்க சன்மானம் வழங்கப்படும் என ஆஸ்திரேலிய போலீஸ் அறிவித்துள்ளது', {'entities': [(99, 113, 'Activity'), (92, 98, 'Public Officer'), (81, 91, 'Location'), (65, 77, 'Activity'), (56, 64, 'Activity'), (40, 50, 'Activity'), (19, 23, 'Crime'), (12, 18, 'Sex'), (7, 11, 'Sex'), (0, 6, 'Location')]}), ('Facebook மூலம் வங்கி கணக்கில் திருடும் Hackers.. Cyber crime எச்சரிக்கை', {'entities': [(61, 71, 'Activity'), (49, 60, 'Public Officer'), (39, 46, 'Suspect'), (30, 38, 'Crime'), (0, 8, 'Organization')]}), ('பல முறை கைது செய்தும் அடங்காத கலையரசி.. பாய்ந்தது குண்டாஸ் வீடியோ', {'entities': [(50, 58, 'Person Name'), (30, 37, 'Person Name'), (13, 21, 'Activity'), (8, 12, 'Activity')]}), ('செல்போன் கடையில் திடீரென வெடித்த செல்போன்.. பலத்த சப்தத்தால் பரபரப்பு வீடியோ', {'entities': [(61, 69, 'Activity'), (50, 60, 'Activity'), (33, 41, 'Object'), (25, 32, 'Activity'), (9, 16, 'Organization'), (0, 8, 'Object')]}), ('அமெரிக்காவில் ஜார்ஜ் மரணம்.. மீண்டும் திரும்பி வந்த Anonymous Hacker குழு', {'entities': [(52, 68, 'Person Name'), (47, 51, 'Activity'), (14, 20, 'Person Name'), (0, 13, 'Location')]}), ('வாலிபரை படுகொலை செய்த மர்மக் கும்பலுக்கு போலீசார் வலைவீச்சு', {'entities': [(50, 59, 'Activity'), (41, 49, 'Public Officer'), (22, 40, 'Suspect'), (16, 21, 'Activity'), (8, 15, 'Crime'), (0, 7, 'Sex')]}), ('செல்போனில் PUBG விளையாடிய சிறுவன் மாரடைப்பால் உயிரிழப்பு', {'entities': [(34, 45, 'Medical Treatment'), (26, 33, 'Sex'), (16, 25, 'Activity'), (11, 15, 'Organization'), (0, 10, 'Object')]}), ('4வதும் பொண்ணு.. கொன்னுட்டோம்', {'entities': [(16, 28, 'Crime'), (7, 13, 'Sex'), (0, 1, 'Numeric')]}), ('தலைக்கேறிய போதை.. நிலைதடுமாறி நீரில் விழுந்து ஒருவர் பலி..', {'entities': [(53, 56, 'Crime'), (46, 52, 'Sex'), (37, 45, 'Activity'), (18, 29, 'Activity'), (11, 15, 'Crime')]}), ('தந்தை உலக்கையால் அடித்து கொலை.. மாத்திரை சாப்பிட சொன்னதால் மகன் ஆத்திரம்..', {'entities': [(59, 63, 'Suspect'), (49, 58, 'Activity'), (41, 48, 'Activity'), (32, 40, 'Object'), (25, 29, 'Crime'), (17, 24, 'Activity'), (0, 5, 'Relation')]}), ('இந்திய பெண் ஒருவர் கொலை வழக்கில் துப்பு கொடுத்தால் தக்க சன்மானம் வழங்கப்படும் என ஆஸ்திரேலிய போலீஸ் அறிவித்துள்ளது', {'entities': [(99, 113, 'Activity'), (92, 98, 'Public Officer'), (81, 91, 'Location'), (65, 77, 'Activity'), (56, 64, 'Activity'), (40, 50, 'Activity'), (19, 23, 'Crime'), (12, 18, 'Sex'), (7, 11, 'Sex'), (0, 6, 'Location')]}), ('Facebook மூலம் வங்கி கணக்கில் திருடும் Hackers.. Cyber crime எச்சரிக்கை', {'entities': [(61, 71, 'Activity'), (49, 60, 'Public Officer'), (39, 46, 'Person Name'), (30, 38, 'Crime'), (15, 20, 'Organization'), (0, 8, 'Organization')]}), ('24 வயது கல்லூரி காதலியைக் கொன்ற 64 வயது பேராசிரியர்... கொடூர குற்றத்திற்கு 12 ஆண்டுகள் சிறை', {'entities': [(78, 86, 'Year'), (75, 77, 'Numeric'), (61, 74, 'Crime'), (40, 51, 'Suspect'), (35, 39, 'Age'), (32, 34, 'Numeric'), (26, 31, 'Crime'), (16, 25, 'Victim'), (8, 15, 'Organization'), (3, 7, 'Age'), (0, 2, 'Numeric')]}), ('ஆர்வமாக செல்போன் பேசிய நபர்.. சட்டென நடந்த விபரீதம்.. சென்னையில் பதிவான பரபரப்பு சிசிடிவி காட்சி', {'entities': [(81, 89, 'Object'), (72, 80, 'Activity'), (65, 71, 'Activity'), (54, 64, 'Location'), (43, 51, 'Activity'), (23, 27, 'Sex'), (17, 22, 'Activity'), (8, 16, 'Object')]}), ('ஜாக்கெட்டில் கழுத்தை நெரித்த சுதா.. கூரைவீட்டில் நடந்த பயங்கரம்.. கடலூர் ஷாக்..', {'entities': [(66, 72, 'Location'), (55, 63, 'Activity'), (36, 48, 'Organization'), (29, 33, 'Person Name'), (21, 28, 'Activity'), (13, 20, 'Part of human body')]}), ('புதருக்குள் சினேகா.. ஒதுக்குப்புறத்தில் நடந்த பயங்கரம்.. சிக்கிய கொடூரன்.. அதிர்ச்சியில் அனந்தபூர்.', {'entities': [(89, 98, 'Location'), (65, 72, 'Suspect'), (57, 64, 'Activity'), (46, 54, 'Activity'), (12, 18, 'Animals')]}), ('ஒரு ரவுடியை தீர்த்து கட்ட.. களத்தில் 30 ரவுடிகள்.. என்னதான் காரணம்.. விசாரணையில் பகீர் தகவல்கள்', {'entities': [(87, 95, 'Activity'), (69, 80, 'Activity'), (60, 66, 'Activity'), (40, 48, 'Person Name'), (37, 39, 'Numeric'), (12, 25, 'Activity'), (4, 11, 'Person Name')]}), ('பச்சை துரோகம்.. சினேகாவை தனியாக அழைத்து சென்று.. புதருக்குள் கொடூரம்.. அலறிய அனந்தபூர்..', {'entities': [(77, 86, 'Location'), (61, 68, 'Crime'), (40, 46, 'Activity'), (32, 39, 'Activity'), (16, 24, 'Person Name')]}), ('காரிலேயே விரட்டி சென்று.. நாம் தமிழர் கட்சி பிரமுகரை வெட்டி சாய்த்த கொடூரம்.. பகீர் பின்னணி..', {'entities': [(68, 75, 'Crime'), (53, 67, 'Crime'), (38, 43, 'Organization'), (26, 37, 'Organization'), (17, 23, 'Activity'), (9, 16, 'Activity'), (0, 8, 'Vehicle')]}), ('டீச்சரை பின்னாடியே துரத்தி சென்று.. கலெக்டர் ஆபீஸ் வாசலிலேயே... அலறிய ராமநாதபுரம்', {'entities': [(70, 81, 'Location'), (64, 69, 'Activity'), (36, 50, 'Organization'), (27, 33, 'Activity'), (19, 26, 'Activity'), (0, 7, 'Profession')]}), ('மொத்தம் 3 பேர்.. 2வது புருஷன்.. லட்சுமியும் உடந்தை.. சுடுகாட்டில் வைத்து.. செங்கல்பட்டில் பயங்கரம்', {'entities': [(75, 89, 'Location'), (32, 43, 'Person Name'), (22, 29, 'Relation'), (17, 18, 'Numeric'), (10, 14, 'Sex'), (8, 9, 'Numeric')]}), ('யாருடனும் பேசவில்லை.. திடீரென கதவை அடைத்து கொண்டு.. அங்கயற்கண்ணி செய்த காரியம்.. பதறிபோன மதுரை', {'entities': [(89, 94, 'Location'), (71, 80, 'Activity'), (65, 70, 'Activity'), (52, 64, 'Person Name'), (35, 42, 'Activity'), (30, 34, 'Object'), (10, 19, 'Activity')]}), ('தனிக்குடித்தனம் போக சொல்லி தகராறு.. 2 மாதத்தில் புதுமாப்பிள்ளை எடுத்த விபரீத முடிவு', {'entities': [(77, 83, 'Activity'), (48, 62, 'Profession'), (38, 47, 'Month'), (36, 37, 'Numeric'), (27, 33, 'Crime'), (20, 26, 'Activity')]}), ('புது தாலியின் ஈரம் கூட காயலை.. ஒரே மாசம்தான்.. இறுதியில் தற்கொலை.. பரிதாப ரக்ஷனா', {'entities': [(74, 80, 'Person Name'), (57, 64, 'Crime'), (35, 44, 'Month'), (23, 28, 'Activity')]}), ('திருமணத்தில் விருப்பம் இல்லை.. தந்தைக்கு வீடியோ அனுப்பிவிட்டு பெண் தற்கொலை.. திருவேற்காட்டில் ஷாக்', {'entities': [(77, 93, 'Location'), (67, 74, 'Crime'), (62, 66, 'Sex'), (31, 40, 'Relation'), (13, 22, 'Activity')]}), ('அசோக் நகரில் சினிமா பாணியில் 12 லட்சம் 45 பவுன் கொள்ளையடித்த போலீஸ்.. காட்டிக் கொடுத்த 3ஆவது கண்', {'entities': [(93, 96, 'Part of human body'), (87, 88, 'Numeric'), (70, 86, 'Activity'), (61, 67, 'Public Officer'), (48, 60, 'Crime'), (42, 47, 'Money'), (39, 41, 'Numeric'), (32, 38, 'Money'), (29, 31, 'Numeric'), (13, 28, 'Organization'), (0, 12, 'Location')]}), ('கோமதியை தரையில் படுக்க வைத்து.. வெலவெலக்க வைத்த குடிகார கணவன்.. சென்னையில் ஷாக்', {'entities': [(64, 74, 'Location'), (56, 61, 'Suspect'), (16, 29, 'Activity'), (0, 7, 'Person Name')]}), ('கொரோனாவால் தொழிலில் நஷ்டம்.. சமாளிக்க முடியாமல் 8 வயது குழந்தை உள்பட 5 பேர் தற்கொலை முயற்சி', {'entities': [(84, 91, 'Activity'), (76, 83, 'Crime'), (71, 75, 'Sex'), (69, 70, 'Numeric'), (50, 54, 'Age'), (48, 49, 'Numeric'), (0, 10, 'Medical Treatment')]}), ('அத்தை மகளுடன் வீடியோ காலில் பேச தடை... ஆத்திரத்தில் பெண் காவலரின் மண்டையை பிளந்த போலீஸ் கணவர்', {'entities': [(88, 93, 'Suspect'), (81, 87, 'Public Officer'), (74, 80, 'Crime'), (66, 73, 'Part of human body'), (57, 65, 'Public Officer'), (52, 56, 'Sex'), (32, 35, 'Activity'), (28, 31, 'Activity'), (6, 13, 'Relation'), (0, 5, 'Relation')]}),('தடை செய்யப்பட்ட 3 நம்பர் லாட்டரி விற்பனை... முதலாளி உள்ளிட்ட 2 பேர் கைது', {'entities': [(68, 72, 'Activity'), (61, 62, 'Numeric'), (44, 51, 'Profession'), (33, 40, 'Activity'), (25, 32, 'Object'), (18, 24, 'Numeric'), (16, 17, 'Numeric'), (0, 3, 'Restricted')]}), ('சத்தியமங்கலம் சட்ட விரோத மின் வேலியில் சிக்கி உயிரிழந்த ஆண் யானை தோட்ட உரிமையாளர் கைது', {'entities': [(82, 86, 'Activity'), (71, 81, 'Profession'), (60, 64, 'Animals'), (56, 59, 'Sex'), (25, 38, 'Object'), (14, 24, 'Restricted'), (0, 13, 'Location')]}), ('திண்டுக்கல் நிதி நிறுவனம் நடத்தி ரூ.40 கோடி மோசடி தம்பதி உட்பட 3 பேர் கைது', {'entities': [(63, 64, 'Numeric'), (50, 56, 'Relation'), (44, 49, 'Crime'), (33, 43, 'Money'), (12, 25, 'Organization'), (0, 11, 'Location')]}), ('மதுரையில் 16 வயது சிறுமிக்கு நடந்த கொடூரம் பாலியல் தொழிலில் ஈடுபடுத்திய பெண்கள் கைது', {'entities': [(80, 84, 'Activity'), (72, 79, 'Sex'), (60, 71, 'Activity'), (43, 59, 'Crime'), (35, 42, 'Activity'), (18, 28, 'Relation'), (13, 17, 'Age'), (10, 12, 'Numeric'), (0, 9, 'Location')]}), ('சென்னை காப்பகத்தில் பெங்களூர் சிறுமிக்கு பாலியல் தொல்லை வாட்ச்மேனால் நேர்ந்த கொடூரம்', {'entities': [(77, 84, 'Activity'), (56, 68, 'Suspect'), (41, 55, 'Crime'), (30, 40, 'Victim'), (20, 29, 'Location'), (7, 19, 'Location'), (0, 6, 'Location')]}), ('பெங்களூரு லோன் ஆப் மூலம் கடன் பெற்றவருக்கு மிரட்டல் போலீஸ் வழக்குப்பதிவு', {'entities': [(59, 72, 'Crime'), (52, 58, 'Public Officer'), (43, 51, 'Activity'), (10, 14, 'Money'), (0, 9, 'Location')]}), ('ஆக்கிரமிப்பை அகற்றிய போலீஸ் முகத்தில் கொதிக்கும் தேநீரை ஊற்றியப் பெண் பீகார் அதிர்ச்சி', {'entities': [(65, 69, 'Sex'), (56, 64, 'Activity'), (38, 55, 'Object'), (21, 27, 'Public Officer'), (0, 12, 'Activity')]}), ('விருதுநகர் போக்சோ வழக்கில் தேடப்பட்ட நபர் தூக்கில் தொங்கிய நிலையில் சடலமாக மீட்பு', {'entities': [(75, 81, 'Activity'), (51, 58, 'Activity'), (37, 41, 'Suspect'), (27, 36, 'Activity'), (11, 26, 'Crime'), (0, 10, 'Location')]}), ('1 கோடி மதிப்பிலான 863 செல்போன்களை மீட்ட சென்னை காவல்துறை 3 மாதங்களில் அதிரடி நடவடிக்கை', {'entities': [(77, 86, 'Activity'), (59, 69, 'Month'), (57, 58, 'Numeric'), (47, 56, 'Public Officer'), (40, 46, 'Location'), (34, 39, 'Activity'), (22, 33, 'Object'), (18, 21, 'Numeric'), (0, 6, 'Money')]}), ('அறுவை சிகிச்சைக்கு வந்த பெண்ணுக்கு பாலியல் தொல்லை கொடுத்த வார்டுபாய் மும்பை அதிர்ச்சி', {'entities': [(69, 75, 'Location'), (58, 68, 'Suspect'), (35, 49, 'Crime'), (24, 34, 'Victim'), (0, 18, 'Medical Treatment')]}), ('கேரள கன்னியாஸ்திரி கொலை வழக்கில் உயர்ந்த மனிதனாக நிற்கும் ’திருடன்’ நெகிழ வைத்த சாட்சியம்', {'entities': [(80, 89, 'Activity'), (68, 73, 'Object'), (59, 66, 'Suspect'), (19, 23, 'Crime'), (5, 18, 'Relation'), (0, 4, 'Location')]}), ('சேலத்தில் ரவுடி வெட்டிக் கொலை பின்னணியில் ரேஷன் பொருள் கடத்தல் சம்பவம்', {'entities': [(63, 70, 'Crime'), (55, 62, 'Crime'), (48, 54, 'Object'), (42, 47, 'Organization'), (25, 29, 'Crime'), (16, 24, 'Activity'), (10, 15, 'Profession'), (0, 9, 'Location')]}), ('காவல்துறையை பழிவாங்க ஸ்கெட்ச் ஒரு சைக்கிள் திருடனின் மறுபக்கம்', {'entities': [(43, 52, 'Crime'), (34, 42, 'Object'), (21, 29, 'Activity'), (12, 20, 'Activity'), (0, 11, 'Public Officer')]}), ('ஆன் லைன் ஆப் மூலம் ரூ.4000 கடன் நிறுவனம் கொடுத்த நெருக்கடியால் இளைஞர் தற்கொலை', {'entities': [(70, 77, 'Crime'), (63, 69, 'Sex'), (49, 62, 'Activity'), (41, 48, 'Activity'), (32, 40, 'Organization'), (19, 26, 'Money'), (9, 12, 'Object')]}), ('காதல் திருமணம் நடத்தையில் சந்தேகம் விவாகரத்து கோரியதால் மனைவியை வெட்டிக்கொன்ற கணவர்', {'entities': [(78, 83, 'Suspect'), (64, 77, 'Crime'), (56, 63, 'Victim'), (35, 45, 'Activity'), (15, 25, 'Activity'), (0, 5, 'Relation')]}), ('சுரேஷ் ரெய்னா கைதாகி ஜாமீனில் விடுதலை', {'entities': [(30, 37, 'Activity'), (14, 20, 'Activity'), (0, 13, 'Person Name')]}), ('அபயா கொலையில் இருவர் குற்றவாளிகள் கேரளாவை உலுக்கிய வழக்கில் 28 ஆண்டுகளுக்கு பின் தீர்ப்பு', {'entities': [(81, 89, 'Activity'), (63, 75, 'Year'), (60, 62, 'Numeric'), (42, 50, 'Activity'), (34, 41, 'Location'), (21, 33, 'Suspect'), (14, 20, 'Numeric'), (5, 13, 'Crime'), (0, 4, 'Person Name')]}), ('உ.பி 13 வயது சிறுமிக்கு நேர்ந்த கொடூரம் போலீஸ் விசாரணை', {'entities': [(47, 54, 'Activity'), (40, 46, 'Public Officer'), (32, 39, 'Crime'), (24, 31, 'Activity'), (13, 23, 'Victim'), (8, 12, 'Age'), (5, 7, 'Numeric'), (0, 4, 'Location')]}), ('நீரவ் மோடி செய்ததை விட பெரியது... செருகுரி ஸ்ரீதர் செய்த ரூ.7296 கோடி நிதி மோசடி', {'entities': [(75, 80, 'Crime'), (70, 74, 'Money'), (57, 69, 'Money'), (34, 50, 'Person Name'), (11, 18, 'Activity'), (0, 10, 'Person Name')]}), ('துபாய் டூ சென்னை விமானத்தில் கடத்தி வரப்பட்ட சிறுத்தை பற்கள்', {'entities': [(54, 60, 'Object'), (45, 53, 'Animals'), (36, 44, 'Activity'), (29, 35, 'Crime'), (17, 28, 'Organization'), (10, 16, 'Location'), (0, 6, 'Location')]}), ('புற்றுநோய் இருப்பதாக கூறி 1.47 கோடி ஏமாற்றிவிட்டார்’ மருத்துவர் மீது பெண் புகார்', {'entities': [(74, 80, 'Activity'), (69, 73, 'Sex'), (53, 63, 'Suspect'), (36, 51, 'Crime'), (26, 35, 'Money'), (21, 25, 'Activity'), (0, 10, 'Medical Treatment')]}), ('ரூ19 கோடி மதிப்பிலான வைரங்கள் மோசடி நிரவ் மோடியின் சகோதரர் மீது குற்றச்சாட்டு', {'entities': [(64, 77, 'Activity'), (51, 58, 'Relation'), (36, 50, 'Person Name'), (30, 35, 'Crime'), (21, 29, 'Object'), (0, 9, 'Money')]}), ('எனது வாட்ஸ்அப் இனி இயங்காது கொலையாவதற்கு முன் மாற்றுத்திறனாளி பெண் அனுப்பிய இறுதி மெசேஜ்', {'entities': [(82, 88, 'Activity'), (62, 66, 'Sex'), (46, 61, 'Handicapped'), (28, 40, 'Crime'), (19, 27, 'Activity'), (5, 14, 'Organization')]}), ('மதுரை மென்பொறியாளர் கொலையில் வடமாநில நபர் தொடர்பா போலீஸ் விசாரணை', {'entities': [(57, 64, 'Activity'), (50, 56, 'Public Officer'), (29, 36, 'Location'), (20, 28, 'Crime'), (6, 19, 'Profession'), (0, 5, 'Location')]}), ('மதுரை சிறுமிக்கு திருமண ஆசைகாட்டி ஏமாற்றிய வாலிபர் போக்சோ சட்டத்தில் கைது', {'entities': [(69, 73, 'Activity'), (51, 68, 'Crime'), (43, 50, 'Suspect'), (6, 16, 'Sex'), (0, 5, 'Location')]}), ('சாப்பிட்ட உணவுக்கு பில் கேட்ட ஊழியர்களிடம் போதையில் தகராறு செய்த சப்இன்ஸ்பெக்டர்', {'entities': [(65, 80, 'Public Officer'), (52, 58, 'Crime'), (30, 42, 'Profession'), (19, 23, 'Object'), (10, 18, 'Object'), (0, 9, 'Activity')]}), ('103 கிலோ தங்கம் காணாமல்போன வழக்கு முன்னாள் டிஜிபியிடம் விசாரிக்க சிபிஐ திட்டம்', {'entities': [(65, 70, 'Public Officer'), (55, 64, 'Activity'), (43, 54, 'Public Officer'), (9, 15, 'Object'), (0, 3, 'Numeric')]}), ('காட்பாடி நடந்து சென்ற பெண்ணை கீழே தள்ளி கழுத்திலிருந்த தங்க நகை பறிப்பு வீடியோ', {'entities': [(64, 71, 'Crime'), (55, 63, 'Object'), (40, 54, 'Part of human body'), (34, 39, 'Activity'), (22, 28, 'Victim'), (16, 21, 'Activity'), (0, 8, 'Location')]}), ('துண்டு துண்டாக சூட்கேஸில் சடலம் அலுவலக தோழியை பார்க்க சென்றவருக்கு நேர்ந்த விபரீதம்', {'entities': [(75, 83, 'Crime'), (67, 74, 'Activity'), (54, 66, 'Victim'), (32, 45, 'Profession'), (15, 25, 'Object')]}), ('லஞ்சத்த கையில கொடுக்காதீங்க.. பின்பாக்கெட்ல வைங்க வீடியோவால் சிக்கிக் கொண்ட பெண் காவலர்', {'entities': [(81, 87, 'Public Officer'), (76, 80, 'Sex'), (50, 60, 'Object'), (44, 49, 'Activity'), (0, 7, 'Money')]}), ('கூட்டுப்பாலியல் வன்கொடுமை ஹத்ராஸ் வழக்கில் குற்றப்பத்திரிகை தாக்கல் செய்தது சிபிஐ', {'entities': [(76, 81, 'Public Officer'), (43, 59, 'Object'), (16, 25, 'Crime'), (0, 15, 'Crime')]}), ('பீகார் கால்நடை திருட்டு சந்தேகம் இளைஞரை அடித்துக்கொன்ற கும்பல்', {'entities': [(40, 54, 'Crime'), (24, 39, 'Suspect'), (15, 23, 'Crime'), (7, 14, 'Animals'), (0, 6, 'Location')]}), ('4 வயது சிறுமிக்கு பாலியல் வன்கொடுமை தனியார் பள்ளி வாகன ஓட்டுநர் உதவியாளருக்கு..', {'entities': [(50, 63, 'Suspect'), (36, 49, 'Organization'), (18, 35, 'Crime'), (7, 17, 'Victim'), (2, 6, 'Age'), (0, 1, 'Numeric')]}), ('விதிகளை மீறி நைட் கிளப் கொண்டாட்டம் சுரேஷ் ரெய்னா உட்பட 34 பேர் கைது', {'entities': [(64, 68, 'Activity'), (56, 58, 'Numeric'), (36, 49, 'Person Name'), (24, 35, 'Activity'), (13, 23, 'Organization')]}), ('மருத்துவப் படிப்புக்கு சீட் வாங்கித் தருவதாகப் பண மோசடி பாமக முன்னாள் நகரச்...', {'entities': [(56, 60, 'Organization'), (50, 55, 'Crime'), (47, 49, 'Money'), (37, 46, 'Activity'), (28, 36, 'Activity'), (23, 27, 'Object')]}), ('முகநூலில் அறிமுகமான சிறுமியை திருமணம் செய்வதாக கூறி கடத்திய இளைஞர் கைது போக்சோ...', {'entities': [(72, 81, 'Crime'), (60, 66, 'Suspect'), (52, 59, 'Crime'), (20, 28, 'Victim')]}), ('மதுரையில் லஞ்ச வழக்கில் சிறை தண்டனை பெற்ற காவல் ஆய்வாளர் மனைவியைக் கொன்று...', {'entities': [(67, 73, 'Crime'), (57, 66, 'Relation'), (42, 56, 'Public Officer'), (24, 35, 'Crime'), (10, 14, 'Money'), (0, 9, 'Location')]}), ('பட்டா பெயர் மாற்றம் செய்ய ரூ.2500 லஞ்சம் வாங்கிய விஏஓ கைது', {'entities': [(54, 58, 'Activity'), (49, 53, 'Profession'), (41, 48, 'Activity'), (26, 40, 'Money'), (12, 25, 'Activity')]}), ('தமிழகத்தில் 7 ஐபிஎஸ் அதிகாரிகள் திடீர் இடமாற்றம்', {'entities': [(39, 48, 'Activity'), (14, 31, 'Profession'), (12, 13, 'Numeric'), (0, 11, 'Location')]}), ('சித்ரா தற்கொலை வழக்கு ஹேம்நாத் கைது பின்னணி என்ன', {'entities': [(31, 35, 'Crime'), (22, 30, 'Person Name'), (7, 14, 'Crime'), (0, 6, 'Person Name')]}), ('தேனியில் கர்ப்பிணி மனைவியைக் கொன்ற கணவருக்கு மரண தண்டனை நீதிமன்றம் தீர்ப்பு', {'entities': [(67, 75, 'Activity'), (45, 55, 'Activity'), (35, 44, 'Suspect'), (29, 34, 'Crime'), (9, 28, 'Victim'), (0, 8, 'Location')]}), ('சோளிங்கர் ஸ்ரீ யோக லட்சுமி நரசிம்மசுவாமி கோயில் குளத்தில் குளிக்கச் சென்ற 2...', {'entities': [(77, 78, 'Numeric'), (61, 70, 'Activity'), (51, 60, 'Location'), (43, 50, 'Organization'), (16, 42, 'Person Name'), (11, 15, 'Sex'), (0, 10, 'Location')]}), ('ஆ.ராசா மீது திடீர் வழக்குப்பதிவு முதல்வருக்கு எதிராக அவதூறாக பேசியதாக புகார்', {'entities': [(53, 69, 'Activity'), (19, 32, 'Activity'), (0, 6, 'Person Name')]}), ('ஒப்பந்தப் பணியாளருக்கு பாலியல் தொந்தரவு மதுரை மாநகராட்சி சுகாதார ஆய்வாளர் மீது வழக்கு', {'entities': [(79, 85, 'Activity'), (57, 73, 'Suspect'), (46, 56, 'Organization'), (40, 45, 'Location'), (23, 39, 'Crime'), (10, 22, 'Victim')]}), ('மதுரை அருகே தனியார் பேருந்து மோதி ஆட்டோவில் பயணித்த இருவர் பலி', {'entities': [(59, 62, 'Activity'), (52, 58, 'Numeric'), (34, 43, 'Vehicle'), (12, 28, 'Vehicle'), (0, 5, 'Location')]}), ('காரைக்குடி அருகே குழந்தையைக் கடத்தி நாடகமாடிய பாட்டி துரிதமாக செயல்பட்டு மீட்ட போலீஸார்', {'entities': [(79, 87, 'Public Officer'), (73, 78, 'Activity'), (62, 72, 'Activity'), (46, 52, 'Suspect'), (29, 35, 'Activity'), (17, 28, 'Victim'), (0, 10, 'Location')]}), ('சிவகங்கையில் முதல்வர் நிகழ்ச்சிக்கு பெற்றோர் சென்றுவிட எதிர்பாராமல் விபத்தில் இறந்த 4 வயது...', {'entities': [(86, 93, 'Age'), (84, 85, 'Numeric'), (45, 54, 'Activity'), (36, 44, 'Relation'), (13, 21, 'Profession'), (0, 12, 'Location')]}), ('கேரளாவில் நாயை காரில் கட்டி இழுத்து சென்ற நபர் கைது..', {'entities': [(47, 51, 'Activity'), (42, 46, 'Suspect'), (28, 35, 'Activity'), (15, 21, 'Vehicle'), (10, 14, 'Animals'), (0, 9, 'Location')]}), ('பிறந்த குழந்தை தம்பியின் ஜாடையில் இருந்ததால் கொலை செய்த தந்தை.. ஈரோட்டில் அதிர்ச்சி', {'entities': [(64, 73, 'Location'), (56, 61, 'Suspect'), (50, 55, 'Activity'), (45, 49, 'Crime'), (15, 24, 'Relation')]}), ('தங்கையுடன் குடும்பம் நடத்தி வந்த வாலிபர் ஓட ஓட வெட்டிக்கொலை.. நெல்லை பயங்கரம்', {'entities': [(62, 68, 'Location'), (47, 59, 'Crime'), (44, 46, 'Activity'), (41, 43, 'Activity'), (21, 32, 'Activity')]}), ('கருப்பு சட்டை எதிர் வீட்டு வாலிபர் ஈர்ப்பு', {'entities': [(35, 42, 'Activity'), (20, 26, 'Organization'), (0, 13, 'Object')]}), ('சித்ராவின் மரணத்தை குறித்து ஹேமந்த் கூறிய முக்கிய தகவல்', {'entities': [(36, 41, 'Activity'), (28, 35, 'Person Name'), (11, 18, 'Crime'), (0, 10, 'Person Name')]}), ('ஏழு வருட வேதனை 14 வயதில் தொடங்கிய பலாத்காரம்', {'entities': [(34, 44, 'Crime'), (25, 33, 'Activity'), (18, 24, 'Age'), (15, 17, 'Numeric'), (4, 8, 'Year'), (0, 3, 'Numeric')]}), ('மீனாட்சி அம்மன் கோயிலில் பெரும்பாலானவர்கள் போலி களையெடுக்கும் பணி தீவிரம்', {'entities': [(62, 65, 'Activity'), (43, 61, 'Crime'), (16, 24, 'Organization'), (0, 15, 'Person Name')]}), ('மனைவிக்கு பயந்து விடுப்பு விண்ணப்பம் அளித்த காவலர்.. வித்தியாச பின்குறிப்பு', {'entities': [(63, 75, 'Activity'), (44, 50, 'Public Officer'), (37, 43, 'Activity'), (0, 9, 'Relation')]}), ('கனிமொழி பிரச்சாரத்தில் லட்ச ரூபாய்க்கு மேல் பிக்பாக்கெட் 3பேர்தான் இதைச் செய்தது', {'entities': [(73, 80, 'Activity'), (58, 66, 'Sex'), (57, 58, 'Numeric'), (44, 56, 'Crime'), (23, 38, 'Money'), (8, 22, 'Activity'), (0, 7, 'Person Name')]}), ('திருப்பத்தூரில் கணவன் பிள்ளைகளை பெட்ரோல் ஊற்றி எரித்த மனைவி..', {'entities': [(54, 59, 'Suspect'), (47, 53, 'Crime'), (41, 46, 'Activity'), (32, 40, 'Object'), (22, 31, 'Victim'), (16, 21, 'Victim'), (0, 15, 'Location')]}), ('சித்ரா முகத்தில் இருந்த நக கீறல் யாருடையது பிரேத பரிசோதனை வெளியானது...', {'entities': [(58, 67, 'Activity'), (49, 57, 'Activity'), (24, 26, 'Object'), (7, 16, 'Part of human body'), (0, 6, 'Person Name')]}), ('20 முறை பறந்த துப்பாக்கி குண்டுகள் மாயமான தங்க நகைகள் திக் திக் நிமிடங்கள்', {'entities': [(64, 74, 'Time'), (42, 53, 'Object'), (25, 34, 'Object'), (14, 24, 'Object'), (0, 2, 'Numeric')]}), ('அசிங்கமா இருக்கு கதறும் சூர்யாவின் டிக்டாக் ஜோடி ரவுடி பேபிக்கு நடந்தது என்ன', {'entities': [(49, 54, 'Person Name'), (44, 48, 'Relation'), (35, 43, 'Organization'), (24, 34, 'Person Name'), (17, 23, 'Activity')]}), ('மசாஜ் சென்டரில் மஜா டிக்டாக் புகழ் ரவுடி பேபி சூர்யா கைது', {'entities': [(46, 52, 'Person Name'), (35, 40, 'Person Name'), (29, 34, 'Activity'), (20, 28, 'Organization'), (0, 15, 'Organization')]}), ('விருந்தில் சாப்பிட்ட தலித் இளைஞர் அடித்துக் கொலை', {'entities': [(44, 48, 'Crime'), (34, 43, 'Activity'), (27, 33, 'Sex'), (21, 26, 'Activity'), (11, 20, 'Activity')]}), ('சித்ரா கன்னத்தில் இரத்தக் கறை மரணத்தின் பின்னுள்ள மர்மம் என்ன', {'entities': [(50, 56, 'Crime'), (30, 39, 'Crime'), (26, 29, 'Object'), (7, 17, 'Part of human body'), (0, 6, 'Person Name')]}), ('சென்னையில் நடந்து சென்ற கர்ப்பிணி மீது கார் மோதி பலி அரசு பெண் அதிகாரி தப்பியோட்டம்', {'entities': [(71, 83, 'Activity'), (63, 70, 'Public Officer'), (58, 62, 'Sex'), (53, 57, 'Organization'), (49, 52, 'Crime'), (44, 48, 'Activity'), (39, 43, 'Vehicle'), (24, 33, 'Sex'), (18, 23, 'Activity'), (11, 17, 'Activity'), (0, 10, 'Location')]}), ('அவதூறு வழக்கில் கைதான ஓய்வு பெற்ற நீதிபதி கர்ணனுக்கு உடல்நலக் குறைவு', {'entities': [(53, 68, 'Medical Treatment'), (42, 52, 'Person Name'), (34, 41, 'Public Officer'), (16, 21, 'Activity'), (0, 15, 'Crime')]}), ('வாலிபரை படுகொலை செய்த மர்மக் கும்பலுக்கு போலீசார் வலைவீச்சு', {'entities': [(50, 59, 'Activity'), (41, 49, 'Public Officer'), (22, 40, 'Suspect'), (16, 21, 'Activity'), (8, 15, 'Crime'), (0, 7, 'Sex')]}), ('செல்போனில் PUBG விளையாடிய சிறுவன் மாரடைப்பால் உயிரிழப்பு', {'entities': [(34, 45, 'Medical Treatment'), (26, 33, 'Sex'), (16, 25, 'Activity'), (11, 15, 'Organization'), (0, 10, 'Object')]}), ('தலைக்கேறிய போதை.. நிலைதடுமாறி நீரில் விழுந்து ஒருவர் பலி..', {'entities': [(46, 52, 'Sex'), (37, 45, 'Activity'), (18, 29, 'Activity'), (11, 15, 'Crime')]}), ('தந்தை உலக்கையால் அடித்து கொலை.. மாத்திரை சாப்பிட சொன்னதால் மகன் ஆத்திரம்..', {'entities': [(59, 63, 'Suspect'), (49, 58, 'Activity'), (41, 48, 'Activity'), (25, 29, 'Crime'), (17, 24, 'Activity'), (0, 5, 'Relation')]}), ('இந்திய பெண் ஒருவர் கொலை வழக்கில் துப்பு கொடுத்தால் தக்க சன்மானம் வழங்கப்படும் என ஆஸ்திரேலிய போலீஸ் அறிவித்துள்ளது', {'entities': [(99, 113, 'Activity'), (92, 98, 'Public Officer'), (81, 91, 'Location'), (65, 77, 'Activity'), (56, 64, 'Activity'), (40, 50, 'Activity'), (19, 23, 'Crime'), (12, 18, 'Sex'), (7, 11, 'Sex'), (0, 6, 'Location')]}), ('Facebook மூலம் வங்கி கணக்கில் திருடும் Hackers.. Cyber crime எச்சரிக்கை', {'entities': [(61, 71, 'Activity'), (49, 60, 'Public Officer'), (39, 46, 'Suspect'), (30, 38, 'Crime'), (0, 8, 'Organization')]}), ('பல முறை கைது செய்தும் அடங்காத கலையரசி.. பாய்ந்தது குண்டாஸ் வீடியோ', {'entities': [(50, 58, 'Person Name'), (30, 37, 'Person Name'), (13, 21, 'Activity'), (8, 12, 'Activity')]}), ('செல்போன் கடையில் திடீரென வெடித்த செல்போன்.. பலத்த சப்தத்தால் பரபரப்பு வீடியோ', {'entities': [(61, 69, 'Activity'), (50, 60, 'Activity'), (33, 41, 'Object'), (25, 32, 'Activity'), (9, 16, 'Organization'), (0, 8, 'Object')]}), ('அமெரிக்காவில் ஜார்ஜ் மரணம்.. மீண்டும் திரும்பி வந்த Anonymous Hacker குழு', {'entities': [(52, 68, 'Person Name'), (47, 51, 'Activity'), (14, 20, 'Person Name'), (0, 13, 'Location')]}), ('வாலிபரை படுகொலை செய்த மர்மக் கும்பலுக்கு போலீசார் வலைவீச்சு', {'entities': [(50, 59, 'Activity'), (41, 49, 'Public Officer'), (22, 40, 'Suspect'), (16, 21, 'Activity'), (8, 15, 'Crime'), (0, 7, 'Sex')]}), ('செல்போனில் PUBG விளையாடிய சிறுவன் மாரடைப்பால் உயிரிழப்பு', {'entities': [(34, 45, 'Medical Treatment'), (26, 33, 'Sex'), (16, 25, 'Activity'), (11, 15, 'Organization'), (0, 10, 'Object')]}), ('4வதும் பொண்ணு.. கொன்னுட்டோம்', {'entities': [(16, 28, 'Crime'), (7, 13, 'Sex'), (0, 1, 'Numeric')]}), ('தலைக்கேறிய போதை.. நிலைதடுமாறி நீரில் விழுந்து ஒருவர் பலி..', {'entities': [(53, 56, 'Crime'), (46, 52, 'Sex'), (37, 45, 'Activity'), (18, 29, 'Activity'), (11, 15, 'Crime')]}), ('தந்தை உலக்கையால் அடித்து கொலை.. மாத்திரை சாப்பிட சொன்னதால் மகன் ஆத்திரம்..', {'entities': [(59, 63, 'Suspect'), (49, 58, 'Activity'), (41, 48, 'Activity'), (32, 40, 'Object'), (25, 29, 'Crime'), (17, 24, 'Activity'), (0, 5, 'Relation')]}), ('இந்திய பெண் ஒருவர் கொலை வழக்கில் துப்பு கொடுத்தால் தக்க சன்மானம் வழங்கப்படும் என ஆஸ்திரேலிய போலீஸ் அறிவித்துள்ளது', {'entities': [(99, 113, 'Activity'), (92, 98, 'Public Officer'), (81, 91, 'Location'), (65, 77, 'Activity'), (56, 64, 'Activity'), (40, 50, 'Activity'), (19, 23, 'Crime'), (12, 18, 'Sex'), (7, 11, 'Sex'), (0, 6, 'Location')]}), ('Facebook மூலம் வங்கி கணக்கில் திருடும் Hackers.. Cyber crime எச்சரிக்கை', {'entities': [(61, 71, 'Activity'), (49, 60, 'Public Officer'), (39, 46, 'Person Name'), (30, 38, 'Crime'), (15, 20, 'Organization'), (0, 8, 'Organization')]}), ('24 வயது கல்லூரி காதலியைக் கொன்ற 64 வயது பேராசிரியர்... கொடூர குற்றத்திற்கு 12 ஆண்டுகள் சிறை', {'entities': [(78, 86, 'Year'), (75, 77, 'Numeric'), (61, 74, 'Crime'), (40, 51, 'Suspect'), (35, 39, 'Age'), (32, 34, 'Numeric'), (26, 31, 'Crime'), (16, 25, 'Victim'), (8, 15, 'Organization'), (3, 7, 'Age'), (0, 2, 'Numeric')]}), ('ஆர்வமாக செல்போன் பேசிய நபர்.. சட்டென நடந்த விபரீதம்.. சென்னையில் பதிவான பரபரப்பு சிசிடிவி காட்சி', {'entities': [(81, 89, 'Object'), (72, 80, 'Activity'), (65, 71, 'Activity'), (54, 64, 'Location'), (43, 51, 'Activity'), (23, 27, 'Sex'), (17, 22, 'Activity'), (8, 16, 'Object')]}), ('ஜாக்கெட்டில் கழுத்தை நெரித்த சுதா.. கூரைவீட்டில் நடந்த பயங்கரம்.. கடலூர் ஷாக்..', {'entities': [(66, 72, 'Location'), (55, 63, 'Activity'), (36, 48, 'Organization'), (29, 33, 'Person Name'), (21, 28, 'Activity'), (13, 20, 'Part of human body')]}), ('புதருக்குள் சினேகா.. ஒதுக்குப்புறத்தில் நடந்த பயங்கரம்.. சிக்கிய கொடூரன்.. அதிர்ச்சியில் அனந்தபூர்.', {'entities': [(89, 98, 'Location'), (65, 72, 'Suspect'), (57, 64, 'Activity'), (46, 54, 'Activity'), (12, 18, 'Animals')]}), ('ஒரு ரவுடியை தீர்த்து கட்ட.. களத்தில் 30 ரவுடிகள்.. என்னதான் காரணம்.. விசாரணையில் பகீர் தகவல்கள்', {'entities': [(87, 95, 'Activity'), (69, 80, 'Activity'), (60, 66, 'Activity'), (40, 48, 'Person Name'), (37, 39, 'Numeric'), (12, 25, 'Activity'), (4, 11, 'Person Name')]}), ('பச்சை துரோகம்.. சினேகாவை தனியாக அழைத்து சென்று.. புதருக்குள் கொடூரம்.. அலறிய அனந்தபூர்..', {'entities': [(77, 86, 'Location'), (61, 68, 'Crime'), (40, 46, 'Activity'), (32, 39, 'Activity'), (16, 24, 'Person Name')]}), ('காரிலேயே விரட்டி சென்று.. நாம் தமிழர் கட்சி பிரமுகரை வெட்டி சாய்த்த கொடூரம்.. பகீர் பின்னணி..', {'entities': [(68, 75, 'Crime'), (53, 67, 'Crime'), (38, 43, 'Organization'), (26, 37, 'Organization'), (17, 23, 'Activity'), (9, 16, 'Activity'), (0, 8, 'Vehicle')]}), ('டீச்சரை பின்னாடியே துரத்தி சென்று.. கலெக்டர் ஆபீஸ் வாசலிலேயே... அலறிய ராமநாதபுரம்', {'entities': [(70, 81, 'Location'), (64, 69, 'Activity'), (36, 50, 'Organization'), (27, 33, 'Activity'), (19, 26, 'Activity'), (0, 7, 'Profession')]}), ('மொத்தம் 3 பேர்.. 2வது புருஷன்.. லட்சுமியும் உடந்தை.. சுடுகாட்டில் வைத்து.. செங்கல்பட்டில் பயங்கரம்', {'entities': [(75, 89, 'Location'), (32, 43, 'Person Name'), (22, 29, 'Relation'), (17, 18, 'Numeric'), (10, 14, 'Sex'), (8, 9, 'Numeric')]}), ('யாருடனும் பேசவில்லை.. திடீரென கதவை அடைத்து கொண்டு.. அங்கயற்கண்ணி செய்த காரியம்.. பதறிபோன மதுரை', {'entities': [(89, 94, 'Location'), (71, 80, 'Activity'), (65, 70, 'Activity'), (52, 64, 'Person Name'), (35, 42, 'Activity'), (30, 34, 'Object'), (10, 19, 'Activity')]}), ('தனிக்குடித்தனம் போக சொல்லி தகராறு.. 2 மாதத்தில் புதுமாப்பிள்ளை எடுத்த விபரீத முடிவு', {'entities': [(77, 83, 'Activity'), (48, 62, 'Profession'), (38, 47, 'Month'), (36, 37, 'Numeric'), (27, 33, 'Crime'), (20, 26, 'Activity')]}), ('புது தாலியின் ஈரம் கூட காயலை.. ஒரே மாசம்தான்.. இறுதியில் தற்கொலை.. பரிதாப ரக்ஷனா', {'entities': [(74, 80, 'Person Name'), (57, 64, 'Crime'), (35, 44, 'Month'), (23, 28, 'Activity')]}), ('திருமணத்தில் விருப்பம் இல்லை.. தந்தைக்கு வீடியோ அனுப்பிவிட்டு பெண் தற்கொலை.. திருவேற்காட்டில் ஷாக்', {'entities': [(77, 93, 'Location'), (67, 74, 'Crime'), (62, 66, 'Sex'), (31, 40, 'Relation'), (13, 22, 'Activity')]}), ('அசோக் நகரில் சினிமா பாணியில் 12 லட்சம் 45 பவுன் கொள்ளையடித்த போலீஸ்.. காட்டிக் கொடுத்த 3ஆவது கண்', {'entities': [(93, 96, 'Part of human body'), (87, 88, 'Numeric'), (70, 86, 'Activity'), (61, 67, 'Public Officer'), (48, 60, 'Crime'), (42, 47, 'Money'), (39, 41, 'Numeric'), (32, 38, 'Money'), (29, 31, 'Numeric'), (13, 28, 'Organization'), (0, 12, 'Location')]}), ('கோமதியை தரையில் படுக்க வைத்து.. வெலவெலக்க வைத்த குடிகார கணவன்.. சென்னையில் ஷாக்', {'entities': [(64, 74, 'Location'), (56, 61, 'Suspect'), (16, 29, 'Activity'), (0, 7, 'Person Name')]}), ('கொரோனாவால் தொழிலில் நஷ்டம்.. சமாளிக்க முடியாமல் 8 வயது குழந்தை உள்பட 5 பேர் தற்கொலை முயற்சி', {'entities': [(84, 91, 'Activity'), (76, 83, 'Crime'), (71, 75, 'Sex'), (69, 70, 'Numeric'), (50, 54, 'Age'), (48, 49, 'Numeric'), (0, 10, 'Medical Treatment')]}), ('அத்தை மகளுடன் வீடியோ காலில் பேச தடை... ஆத்திரத்தில் பெண் காவலரின் மண்டையை பிளந்த போலீஸ் கணவர்', {'entities': [(88, 93, 'Suspect'), (81, 87, 'Public Officer'), (74, 80, 'Crime'), (66, 73, 'Part of human body'), (57, 65, 'Public Officer'), (52, 56, 'Sex'), (32, 35, 'Activity'), (28, 31, 'Activity'), (6, 13, 'Relation'), (0, 5, 'Relation')]})]

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
disable_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
with nlp.disable_pipes(*disable_pipes):
    optimizer = nlp.resume_training()
    
    for iteration in range(30):
        random.shuffle(train_data)
        losses = {}
        
        batches = minibatch(train_data, size=compounding(1.0,4.0,1.001))
        for batch in batches:
            text,annotation = zip(*batch)
            nlp.update(
                       text,
                       annotation,
                       drop=0.5,
                       losses=losses,
                       sgd=optimizer
                      )
            print("LOSSES",losses)
# Out:
# LOSSES {'ner': 8.908164203166962}
# LOSSES {'ner': 21.727849900722504}
# LOSSES {'ner': 30.579110860824585}
# LOSSES {'ner': 41.391711831092834}
# LOSSES {'ner': 47.265774726867676}
# LOSSES {'ner': 56.01560002565384}
# LOSSES {'ner': 66.79385197162628}
# LOSSES {'ner': 75.48351776599884}
# LOSSES {'ner': 84.20280522108078}
# LOSSES {'ner': 93.5661872625351}
# LOSSES {'ner': 101.32561737298965}
# LOSSES {'ner': 109.99558061361313}
# LOSSES {'ner': 123.50749731063843}
# LOSSES {'ner': 134.75301724672318}
# LOSSES {'ner': 146.25508975982666}
# LOSSES {'ner': 153.1416153907776}
# LOSSES {'ner': 162.54517823457718}
# LOSSES {'ner': 168.32299119234085}
# LOSSES {'ner': 178.84156000614166}
# LOSSES {'ner': 188.9027918279171}
# ...

# %%
for text, _ in train_data:
    doc = nlp(text)
    print('Entities',[(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('4', 'Numeric'), ('வயது', 'Age'), ('சிறுமிக்கு', 'Victim'), ('பாலியல் வன்கொடுமை', 'Crime'), ('தனியார்', 'Person Name'), ('வாகன ஓட்டுநர்', 'Suspect')]
# Entities [('சுரேஷ் ரெய்னா', 'Person Name'), ('கைதாகி', 'Activity'), ('விடுதலை', 'Activity')]
# Entities [('மீனாட்சி', 'Relation'), ('கோயிலில்', 'Object'), ('போலி களையெடுக்கும்', 'Crime'), ('பணி', 'Activity')]
# Entities [('விருப்பம்', 'Activity'), ('தந்தைக்கு', 'Person Name'), ('பெண்', 'Sex'), ('தற்கொலை', 'Crime'), ('திருவேற்காட்டில்', 'Location')]
# Entities [('திருப்பத்தூரில்', 'Location'), ('கணவன்', 'Victim'), ('பிள்ளைகளை', 'Victim'), ('பெட்ரோல்', 'Object'), ('ஊற்றி', 'Activity'), ('எரித்த', 'Crime'), ('மனைவி', 'Suspect')]
# Entities [('அறுவை', 'Person Name'), ('பெண்ணுக்கு', 'Victim'), ('பாலியல் தொல்லை', 'Crime'), ('வார்டுபாய்', 'Suspect'), ('மும்பை', 'Location')]
# Entities [('தமிழகத்தில்', 'Location'), ('7', 'Numeric'), ('ஐபிஎஸ் அதிகாரிகள்', 'Profession'), ('இடமாற்றம்', 'Activity')]
# ...

# %%
Entity_list1 = []
Entity_list2 = []
for text, _ in train_data:
    for ent in doc.ents:
        doc = nlp(text)
        Entity_list1.append(ent.text)
        Entity_list2.append(ent.label_)

# %%
Entity = pd.DataFrame({'Entity':Entity_list1,
                       'Entity_Name':Entity_list2})

# %%
Entity.head(20)
# Out:
#                 Entity  Entity_Name
# 0             செல்போன்       Object
# 1                பேசிய     Activity
# 2                 நபர்          Sex
# 3             விபரீதம்     Activity
# 4           சென்னையில்     Location
# 5               பதிவான     Activity
# 6             பரபரப்பு     Activity
# 7             சிசிடிவி       Object
# 8                    4      Numeric
# 9                 வயது          Age
# 10          சிறுமிக்கு       Victim
# 11   பாலியல் வன்கொடுமை        Crime
# 12             தனியார்  Person Name
# 13       வாகன ஓட்டுநர்      Suspect
# 14       சுரேஷ் ரெய்னா  Person Name
# 15              கைதாகி     Activity
# 16             விடுதலை     Activity
# 17            மீனாட்சி     Relation
# 18            கோயிலில்       Object
# 19  போலி களையெடுக்கும்        Crime

# %%
output_dir = Path("/home/rebel/Documents/nert")

# %%
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)
# Out:
# Saved model to /home/rebel/Documents/nert

# %%
model = spacy.load('/home/rebel/Documents/nert')

# %%
from spacy import displacy
Test_list1 = []
Test_list2 = []
doc = nlp("அத்தை மகளுடன் வீடியோ காலில் பேச தடை... ஆத்திரத்தில் பெண் காவலரின் மண்டையை பிளந்த போலீஸ் கணவர்")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# அத்தை 0 5 Relation
# மகளுடன் 6 13 Relation
# பேச 28 31 Activity
# தடை 32 35 Activity
# பெண் 52 56 Sex
# காவலரின் 57 65 Public Officer
# மண்டையை 66 73 Part of human body
# பிளந்த 74 80 Crime
# போலீஸ் 81 87 Public Officer
# கணவர் 88 93 Suspect
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     அத்தை
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Relation</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     மகளுடன்
# ...

# %%
from spacy import displacy
Test_list1 = []
Test_list2 = []
doc = nlp("தீபாவளி தீ விபத்தில் வீர மரணம் அடைந்தவர் மனைவி தற்கொலை!")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# தீபாவளி 0 7 Person Name
# அடைந்தவர் 31 40 Activity
# மனைவி 41 46 Sex
# தற்கொலை 47 54 Crime
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     தீபாவளி
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Person Name</span>
# </mark>
#  தீ விபத்தில் வீர மரணம்
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     அடைந்தவர்
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Activity</span>
# </mark>
#
# ...

# %%
from spacy import displacy

doc = nlp("கோவை போலீசை கதறவிட்ட எஸ்டிபிஐ கட்சி விவசாயிகளுக்கு ஆதரவு தெரிவித்து போராட்டம்")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent',jupyter = True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# கோவை 0 4 Relation
# போலீசை 5 11 Object
# கதறவிட்ட 12 20 Activity
# கட்சி 30 35 Object
# விவசாயிகளுக்கு 36 50 Crime
# போராட்டம் 68 77 Activity
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     கோவை
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Relation</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     போலீசை
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Object</span>
# </mark>
#
# ...

# %%
from spacy import displacy

doc = nlp("பட்டப்பகலில் பயங்கரம்... சென்னையில் வாலிபர் சரமாரியாக வெட்டிப்படுகொலை... அலறியடித்து ஓடிய பொதுமக்கள்...")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    Test_list1.append(ent.text)
    Test_list2.append(ent.label_)
displacy.render(nlp(doc.text),style='ent', jupyter=True)
Test = pd.DataFrame({'Entity':Test_list1,
                       'Entity_Name':Test_list2})
Test.head(5)
# Out:
# பயங்கரம் 13 21 Object
# சென்னையில் 25 35 Location
# வெட்டிப்படுகொலை 54 69 Crime
# அலறியடித்து 73 84 Activity
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">பட்டப்பகலில்
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     பயங்கரம்
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Object</span>
# </mark>
# ...
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     சென்னையில்
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Location</span>
# </mark>
#  வாலிபர் சரமாரியாக
# ...

# %%
Test.head(20)
# Out:
#              Entity  Entity_Name
# 0           தீபாவளி  Person Name
# 1         அடைந்தவர்     Activity
# 2             மனைவி          Sex
# 3           தற்கொலை        Crime
# 4              கோவை     Relation
# 5            போலீசை       Object
# 6          கதறவிட்ட     Activity
# 7             கட்சி       Object
# 8    விவசாயிகளுக்கு        Crime
# 9         போராட்டம்     Activity
# 10         பயங்கரம்       Object
# 11       சென்னையில்     Location
# 12  வெட்டிப்படுகொலை        Crime
# 13      அலறியடித்து     Activity
